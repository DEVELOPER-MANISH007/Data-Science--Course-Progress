# %% [markdown]
# ## Part I-Text Classification With Word2vec And AvgWord2vec

# %%
! pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\users\dev_manish\anaconda3\lib\site-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\dev_manish\anaconda3\lib\site-packages (from gensim) (2.3.5)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\dev_manish\anaconda3\lib\site-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in c:\users\dev_manish\anaconda3\lib\site-packages (from gensim) (8.0.1)
# Requirement already satisfied: wrapt in c:\users\dev_manish\anaconda3\lib\site-packages (from smart_open>=1.8.1->gensim) (1.17.0)

# %%
from gensim.models import word2vec,keyedvectors

# %%
import gensim.downloader as api

wv = api.load("word2vec-google-news-300")

vec_king = wv['king']

# %%
import pandas as pd

messages = pd.read_csv('SMSSpamCollection.csv',sep='\t',names=['label','message'])
messages.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
import re
import nltk
nltk.download("stopwords")
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DEV_MANISH\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
corpus = []

for i in range(0,len(messages)):
    review= re.sub('^[Aa-zA-z]',' ', messages['message'][i])
    review = review.lower()
    review = review.split()
    review = [lemmatizer.lemmatize(word)for word  in review]
    review = ' '.join(review)
    corpus.append(review)

# %%
corpus
# Out:
# ['o until jurong point, crazy.. available only in bugis n great world la e buffet... cine there got amore wat...',
#  'k lar... joking wif u oni...',
#  "ree entry in 2 a wkly comp to win fa cup final tkts 21st may 2005. text fa to 87121 to receive entry question(std txt rate)t&c's apply 08452810075over18's",
#  'dun say so early hor... u c already then say...',
#  "ah i don't think he go to usf, he life around here though",
#  "reemsg hey there darling it's been 3 week's now and no word back! i'd like some fun you up for it still? tb ok! xxx std chgs to send, £1.50 to rcv",
#  'ven my brother is not like to speak with me. they treat me like aid patent.',
#  "s per your request 'melle melle (oru minnaminunginte nurungu vettam)' ha been set a your callertune for all callers. press *9 to copy your friend callertune",
#  'inner!! a a valued network customer you have been selected to receivea £900 prize reward! to claim call 09061701461. claim code kl341. valid 12 hour only.',
#  'ad your mobile 11 month or more? u r entitled to update to the latest colour mobile with camera for free! call the mobile update co free on 08002986030',
#  "'m gonna be home soon and i don't want to talk about this stuff anymore tonight, k? i've cried enough today.",
#  'ix chance to win cash! from 100 to 20,000 pound txt> csh11 and send to 87575. cost 150p/day, 6days, 16+ tsandcs apply reply hl 4 info',
#  'rgent! you have won a 1 week free membership in our £100,000 prize jackpot! txt the word: claim to no: 81010 t&c www.dbuk.net lccltd pobox 4403ldnw1a7rw18',
#  "'ve been searching for the right word to thank you for this breather. i promise i wont take your help for granted and will fulfil my promise. you have been wonderful and a blessing at all times.",
#  'have a date on sunday with will!!',
#  'xxmobilemovieclub: to use your credit, click the wap link in the next txt message or click here>> http://wap. xxxmobilemovieclub.com?n=qjkgighjjgcbl',
#  "h k...i'm watching here:)",
#  'h u remember how 2 spell his name... yes i did. he v naughty make until i v wet.',
#  'ine if that\x92s the way u feel. that\x92s the way it gota b',
#  'ngland v macedonia - dont miss the goals/team news. txt ur national team to 87077 eg england to 87077 try:wales, scotland 4txt/ú1.20 poboxox36504w45wq 16+',
#  's that seriously how you spell his name?',
#  '‘m going to try for 2 month ha ha only joking',
#  'o ü pay first lar... then when is da stock comin...',
#  'ft i finish my lunch then i go str down lor. ard 3 smth lor. u finish ur lunch already?',
#  'fffffffff. alright no way i can meet up with you sooner?',
#  "ust forced myself to eat a slice. i'm really not hungry tho. this sucks. mark is getting worried. he know i'm sick when i turn down pizza. lol",
#  'ol your always so convincing.',
#  "id you catch the bus ? are you frying an egg ? did you make a tea? are you eating your mom's left over dinner ? do you feel my love ?",
#  "'m back &amp; we're packing the car now, i'll let you know if there's room",
#  'hhh. work. i vaguely remember that! what doe it feel like? lol',
#  "ait that's still not all that clear, were you not sure about me being sarcastic or that that's why x doesn't want to live with u",
#  "eah he got in at 2 and wa v apologetic. n had fallen out and she wa actin like spoilt child and he got caught up in that. till 2! but we won't go there! not doing too badly cheers. you?",
#  'tell me anything about you.',
#  'or fear of fainting with the of all that housework you just did? quick have a cuppa',
#  'hank for your subscription to ringtone uk your mobile will be charged £5/month please confirm by replying yes or no. if you reply no you will not be charged',
#  'up... ok i go home look at the timing then i msg ü again... xuhui going to learn on 2nd may too but her lesson is at 8am',
#  "ops, i'll let you know when my roommate's done",
#  'see the letter b on my car',
#  'nything lor... u decide...',
#  "ello! how's you and how did saturday go? i wa just texting to see if you'd decided to do anything tomo. not that i'm trying to invite myself or anything!",
#  'l go ahead with watts. i just wanted to be sure. do have a great weekend. abiola',
#  'id i forget to tell you ? i want you , i need you, i crave you ... but most of all ... i love you my sweet arabian steed ... mmmmmm ... yummy',
#  '07732584351 - rodger burn - msg = we tried to call you re your reply to our sm for a free nokia mobile + free camcorder. please call now 08000930705 for delivery tomorrow',
#  'ho are you seeing?',
#  'reat! i hope you like your man well endowed. i am &lt;#&gt; inches...',
#  'o calls..messages..missed call',
#  "idn't you get hep b immunisation in nigeria.",
#  'air enough, anything going on?',
#  "eah hopefully, if tyler can't do it i could maybe ask around a bit",
#  "don't know how stubborn i am. i didn't even want to go to the hospital. i kept telling mark i'm not a weak sucker. hospital are for weak suckers.",
#  'hat you thinked about me. first time you saw me in class.',
#  'gram usually run like &lt;#&gt; , a half eighth is smarter though and get you almost a whole second gram for &lt;#&gt;',
#  "fyi x ha a ride early tomorrow morning but he's crashing at our place tonight",
#  'ow. i never realized that you were so embarassed by your accomodations. i thought you liked it, since i wa doing the best i could and you always seemed so happy about "the cave". i\'m sorry i didn\'t and don\'t have more to give. i\'m sorry i offered. i\'m sorry your room wa so embarassing.',
#  'ms. ac sptv: the new jersey devil and the detroit red wing play ice hockey. correct or incorrect? end? reply end sptv',
#  'o you know what mallika sherawat did yesterday? find out now @ &lt;url&gt;',
#  'ongrats! 1 year special cinema pas for 2 is yours. call 09061209465 now! c suprman v, matrix3, starwars3, etc all 4 free! bx420-ip4-5we. 150pm. dont miss out!',
#  "orry, i'll call later in meeting.",
#  'ell where you reached',
#  'es..gauti and sehwag out of odi series.',
#  "our gonna have to pick up a $1 burger for yourself on your way home. i can't even move. pain is killing me.",
#  'a ha ha good joke. girl are situation seekers.',
#  't a part of checking iq',
#  'orry my roommate took forever, it ok if i come by now?',
#  'k lar i double check wif da hair dresser already he said wun cut v short. he said will cut until i look nice.',
#  's a valued customer, i am pleased to advise you that following recent review of your mob no. you are awarded with a £1500 bonus prize, call 09066364589',
#  'oday is "song dedicated day.." which song will u dedicate for me? send this to all ur valuable frnds but first rply me...',
#  'rgent ur awarded a complimentary trip to eurodisinc trav, aco&entry41 or £1000. to claim txt dis to 87121 18+6*£1.50(morefrmmob. shracomorsglsuplt)10, ls1 3aj',
#  'id you hear about the new "divorce barbie"? it come with all of ken\'s stuff!',
#  'plane to give on this month end.',
#  'ah lucky man... then can save money... hee...',
#  'inished class where are you.',
#  'i babe im at home now wanna do something? xx',
#  '..k:)where are you?how did you performed?',
#  'can call me now...',
#  'am waiting machan. call me once you free.',
#  'hat cool. i am a gentleman and will treat you with dignity and respect.',
#  'like you people very much:) but am very shy pa.',
#  'oes not operate after &lt;#&gt; or what',
#  "t not the same here. still looking for a job. how much do ta's earn there.",
#  "orry, i'll call later",
#  '. did you call me just now ah?',
#  'k i am on the way to home hi hi',
#  'ou will be in the place of that man',
#  'up next stop.',
#  "call you later, don't have network. if urgnt, sm me.",
#  "or real when u getting on yo? i only need 2 more ticket and one more jacket and i'm done. i already used all my multis.",
#  "e i started to send request to make it but pain came back so i'm back in bed. double coin at the factory too. i gotta cash in all my nitros.",
#  "'m really not up to it still tonight babe",
#  'la kano.,il download, come wen ur free..',
#  'eah do! don‘t stand to close tho- you‘ll catch something!',
#  "orry to be a pain. is it ok if we meet another night? i spent late afternoon in casualty and that mean i haven't done any of y stuff42moro and that includes all my time sheet and that. sorry.",
#  'mile in pleasure smile in pain smile when trouble pours like rain smile when sum1 hurt u smile becoz someone still love to see u smiling!!',
#  'lease call our customer service representative on 0800 169 6031 between 10am-9pm a you have won a guaranteed £1000 cash or £5000 prize!',
#  'avent planning to buy later. i check already lido only got 530 show in e afternoon. u finish work already?',
#  'our free ringtone is waiting to be collected. simply text the password "mix" to 85069 to verify. get usher and britney. fml, po box 5249, mk17 92h. 450ppw 16',
#  'atching telugu movie..wat abt u?',
#  'see. when we finish we have load of loan to pay',
#  'i. wk been ok - on hols now! yes on for a bit of a run. forgot that i have hairdresser appointment at four so need to get home n shower beforehand. doe that cause prob for u?"',
#  'see a cup of coffee animation',
#  "lease don't text me anymore. i have nothing else to say.",
#  'kay name ur price a long a it legal! wen can i pick them up? y u ave x am xx',
#  "'m still looking for a car to buy. and have not gone 4the driving test yet.",
#  "s per your request 'melle melle (oru minnaminunginte nurungu vettam)' ha been set a your callertune for all callers. press *9 to copy your friend callertune",
#  "ow. you're right! i didn't mean to do that. i guess once i gave up on boston men and changed my search location to nyc, something changed. cuz on my signin page it still say boston.",
#  'mma my life and vava umma love you lot dear',
#  'hank a lot for your wish on my birthday. thanks you for making my birthday truly memorable.',
#  "ight, i'll hit you up when i get some cash",
#  "ow would my ip address test that considering my computer isn't a minecraft server",
#  'know! grumpy old people. my mom wa like you better not be lying. then again i am always the one to play jokes...',
#  "ont worry. i guess he's busy.",
#  'hat is the plural of the noun research?',
#  'oing for dinner.msg you after.',
#  "'m ok wif it co i like 2 try new things. but i scared u dun like mah. co u said not too loud.",
#  'ent! we are trying to contact you. last weekend draw show that you won a £1000 prize guaranteed. call 09064012160. claim code k52. valid 12hrs only. 150ppm',
#  "a, ur openin sentence very formal... anyway, i'm fine too, juz tt i'm eatin too much n puttin on weight...haha... so anythin special happened?",
#  "s i entered my cabin my pa said, '' happy b'day bos !!''. i felt special. she askd me 4 lunch. after lunch she invited me to her apartment. we went there.",
#  'ou are a winner u have been specially selected 2 receive £1000 or a 4* holiday (flights inc) speak to a live operator 2 claim 0871277810910p/min (18+)',
#  'oodo! yes we must speak friday - egg-potato ratio for tortilla needed!',
#  "mm...my uncle just informed me that he's paying the school directly. so pls buy food.",
#  'rivate! your 2004 account statement for 07742676969 show 786 unredeemed bonus points. to claim call 08719180248 identifier code: 45239 expires',
#  'rgent! your mobile no. wa awarded £2000 bonus caller prize on 5/9/03 this is our final try to contact u! call from landline 09064019788 box42wr29c, 150ppm',
#  'ere is my new address -apples&pairs&all that malarky',
#  'odays voda number ending 7548 are selected to receive a $350 award. if you have a match please call 08712300220 quoting claim code 4041 standard rate app',
#  'am going to sao mu today. will be done only at 12',
#  "ü predict wat time ü'll finish buying?",
#  'ood stuff, will do.',
#  "ust so that you know,yetunde hasn't sent money yet. i just sent her a text not to bother sending. so it over, you dont have to involve yourself in anything. i shouldn't have imposed anything on you in the first place so for that, i apologise.",
#  're you there in room.',
#  'ey girl. how r u? hope u r well me an del r bak! again long time no c! give me a call sum time from lucyxx',
#  '..k:)how much doe it cost?',
#  "'m home.",
#  'ear, will call tmorrow.pls accomodate.',
#  'irst answer my question.',
#  'unshine quiz wkly q! win a top sony dvd player if u know which country the algarve is in? txt ansr to 82277. £1.50 sp:tyrone',
#  "ant 2 get laid tonight? want real dogging location sent direct 2 ur mob? join the uk's largest dogging network bt txting gravel to 69888! nt. ec2a. 31p.msg@150p",
#  "only haf msn. it's yijue@hotmail.com",
#  'e is there. you call and meet him',
#  'o no. i will check all room befor activity',
#  "ou'll not rcv any more msg from the chat svc. for free hardcore service text go to: 69988 if u get nothing u must age verify with yr network & try again",
#  'ot c... i lazy to type... i forgot ü in lect... i saw a pouch but like not v nice...',
#  ", text me when you're on the way",
#  'ir, waiting for your mail.',
#  'swt thought: "nver get tired of doing little thing 4 lovable persons.." coz..somtimes those little thing occupy d biggest part in their hearts.. gud ni8',
#  'know you are. can you pls open the back?',
#  'e see ya not on the dot',
#  'hat the staff name who is taking class for us?',
#  "reemsg why haven't you replied to my text? i'm randy, sexy, female and live local. luv to hear from u. netcollex ltd 08700621170150p per msg reply stop to end",
#  'mmma.will call after check in.our life will begin from qatar so pls pray very hard.',
#  '..i deleted my contact that why?',
#  'indu got job in birla soft ..',
#  "he wine is flowing and i'm i have nevering..",
#  'up i thk cine is better co no need 2 go down 2 plaza mah.',
#  'k... ur typical reply...',
#  "s per your request 'melle melle (oru minnaminunginte nurungu vettam)' ha been set a your callertune for all callers. press *9 to copy your friend callertune",
#  'ou are everywhere dirt, on the floor, the windows, even on my shirt. and sometimes when i open my mouth, you are all that come flowing out. i dream of my world without you, then half my chore are out too. a time of joy for me, lot of tv show i.ll see. but i guess like all thing you just must exist, like rain, hail and mist, and when my time here is done, you and i become one.',
#  'aooooright are you at work?',
#  "'m leaving my house now...",
#  'ello, my love. what are you doing? did you get to that interview today? are you you happy? are you being a good boy? do you think of me?are you missing me ?',
#  'ustomer service annoncement. you have a new year delivery waiting for you. please call 07046744435 now to arrange delivery',
#  'ou are a winner u have been specially selected 2 receive £1000 cash or a 4* holiday (flights inc) speak to a live operator 2 claim 0871277810810',
#  "eep yourself safe for me because i need you and i miss you already and i envy everyone that see's you in real life",
#  'ew car and house for my parents.:)i have only new job in hand:)',
#  "'m so in love with you. i'm excited each day i spend with you. you make me so happy.",
#  '-pls stop bootydelious (32/f) is inviting you to be her friend. reply yes-434 or no-434 see her: www.sms.ac/u/bootydelious stop? send stop frnd to 62468',
#  'angbabes ur order is on the way. u should receive a service msg 2 download ur content. if u do not, goto wap. bangb. tv on ur mobile internet/service menu',
#  'place all ur point on e culture module already.',
#  'rgent! we are trying to contact you. last weekend draw show that you have won a £900 prize guaranteed. call 09061701939. claim code s89. valid 12hrs only',
#  "i frnd, which is best way to avoid missunderstding wit our beloved one's?",
#  'reat escape. i fancy the bridge but need her lager. see you tomo',
#  'e :)it completely in out of form:)clark also utter waste.',
#  'ir, i need axis bank account no and bank address.',
#  'mmm.. thk sure got time to hop ard... ya, can go 4 free abt... muz call u to discus liao...',
#  'hat time you coming down later?',
#  'loody hell, cant believe you forgot my surname mr . ill give u a clue, it spanish and begin with m...',
#  "ell, i'm gonna finish my bath now. have a good...fine night.",
#  "et me know when you've got the money so carlos can make the call",
#  'still going to the mall?',
#  "urn out my friend are staying for the whole show and won't be back til ~ &lt;#&gt; , so feel free to go ahead and smoke that $ &lt;#&gt; worth",
#  'ext her. if she doesnt reply let me know so i can have her log in',
#  "i! you just spoke to maneesha v. we'd like to know if you were satisfied with the experience. reply toll free with yes or no.",
#  'ou lifted my hope with the offer of money. i am in need. especially when the end of the month approach and it hurt my studying. anyways have a gr8 weekend',
#  'ol no. u can trust me.',
#  'k. i am a gentleman and will treat you with dignity and respect.',
#  'e will, you guy close?',
#  'oing on nothing great.bye',
#  "ello handsome ! are you finding that job ? not being lazy ? working towards getting back that net for mummy ? where's my boytoy now ? doe he miss me ?",
#  'aha awesome, be there in a minute',
#  'lease call our customer service representative on freephone 0808 145 4742 between 9am-11pm a you have won a guaranteed £1000 cash or £5000 prize!',
#  'ave you got xmas radio times. if not i will get it now',
#  'jus reached home. i go bathe first. but my si using net tell u when she finish k...',
#  're you unique enough? find out from 30th august. www.areyouunique.co.uk',
#  "'m sorry. i've joined the league of people that dont keep in touch. you mean a great deal to me. you have been a friend at all time even at great personal cost. do have a great week.|",
#  'i :)finally i completed the course:)',
#  't will stop on itself. i however suggest she stay with someone that will be able to give or for every stool.',
#  "ow are you doing? hope you've settled in for the new school year. just wishin you a gr8 day",
#  'ud mrng dear hav a nice day',
#  'id u got that person story',
#  's your hamster dead? hey so tmr i meet you at 1pm orchard mrt?',
#  'i it kate how is your evening? i hope i can see you tomorrow for a bit but i have to bloody babyjontet! txt back if u can. :) xxx',
#  'ound it, enc &lt;#&gt; , where you at?',
#  'sent you &lt;#&gt; buck',
#  'ello darlin ive finished college now so txt me when u finish if u can love kate xxx',
#  'our account ha been refilled successfully by inr &lt;decimal&gt; . your keralacircle prepaid account balance is r &lt;decimal&gt; . your transaction id is kr &lt;#&gt; .',
#  'oodmorning sleeping ga.',
#  'call me alter at 11 ok.',
#  'ü say until like dat i dun buy ericsson oso cannot oredi lar...',
#  "s i entered my cabin my pa said, '' happy b'day bos !!''. i felt special. she askd me 4 lunch. after lunch she invited me to her apartment. we went there.",
#  'ight yo, dat straight dogg',
#  'ou please give u connection today itself before &lt;decimal&gt; or refund the bill',
#  'oth :) i shoot big load so get ready!',
#  "hat's up bruv, hope you had a great break. do have a rewarding semester.",
#  'ome so we can always chat',
#  ':)k:)good:)study well.',
#  'up... how ü noe leh...',
#  'ounds great! are you home now?',
#  'inally the match heading towards draw a your prediction.',
#  "ired. i haven't slept well the past few nights.",
#  'asy ah?sen got selected mean it good..',
#  'have to take exam with march 3',
#  "eah you should. i think you can use your gt atm now to register. not sure but if there's anyway i can help let me know. but when you do be sure you are ready.",
#  'k no prob. take ur time.',
#  'here is o called ubandu which will run without installing in hard disk...you can use that o to copy the important file in system and give it to repair shop..',
#  "orry, i'll call later",
#  'say leh... of course nothing happen lar. not say v romantic jus a bit only lor. i thk e nite scenery not so nice leh.',
#  '500 new mobile from 2004, must go! txt: nokia to no: 89545 & collect yours today!from only £1 www.4-tc.biz 2optout 087187262701.50gbp/mtmsg18',
#  'ould really appreciate if you call me. just need someone to talk to.',
#  'ill u meet ur dream partner soon? is ur career off 2 a flyng start? 2 find out free, txt horo followed by ur star sign, e. g. horo aries',
#  'ey company elama po mudyadhu.',
#  'ife is more strict than teacher... bcoz teacher teach lesson &amp; then conduct exam, but life first conduct exam &amp; then teach lessons. happy morning. . .',
#  'ear good morning now only i am up',
#  'et down in gandhipuram and walk to cross cut road. right side &lt;#&gt; street road and turn at first right.',
#  'ear we are going to our rubber place',
#  "orry battery died, yeah i'm here",
#  'es:)here tv is always available in work place..',
#  'ext & meet someone sexy today. u can find a date or even flirt it up to u. join 4 just 10p. reply with name & age eg sam 25. 18 -msg recd@thirtyeight penny',
#  'have printed it oh. so &lt;#&gt; come upstairs',
#  'r ill be a little closer like at the bus stop on the same street',
#  'here are you?when wil you reach here?',
#  "ew theory: argument win d situation, but loses the person. so dont argue with ur friend just.. . . . kick them &amp; say, i'm always correct.!",
#  '447801259231 have a secret admirer who is looking 2 make contact with u-find out who they r*reveal who think ur so special-call on 09058094597',
#  'omarrow final hearing on my laptop case so i cant.',
#  'leassssssseeeeee tel me v avent done sportsx',
#  'kay. no no, just shining on. that wa meant to be signing, but that sound better.',
#  "lthough i told u dat i'm into baig face watch now but i really like e watch u gave co it's fr u. thanx 4 everything dat u've done today, i'm touched...",
#  "don't remember that old commercial?",
#  "oo late. i said i have the website. i didn't i have or dont have the slipper",
#  'asked you to call him now ok',
#  'allis wont bat in 2nd innings.',
#  't didnt work again oh. ok goodnight then. i.ll fix and have it ready by the time you wake up. you are very dearly missed have a good night sleep.',
#  'ongratulations ur awarded 500 of cd voucher or 125gift guaranteed & free entry 2 100 wkly draw txt music to 87066 tncs www.ldew.com1win150ppmx3age16',
#  'anjith cal drpd deeraj and deepak 5min hold',
#  'en ur lovable bcums angry wid u, dnt take it seriously.. coz being angry is d most childish n true way of showing deep affection, care n luv!.. kettoda manda... have nice day da.',
#  'hat you doing?how are you?',
#  'p which is 3days also, and the shipping company that take 2wks. the other way is usps which take a week but when it get to lag you may have to bribe nipost to get your stuff.',
#  "'m back, lemme know when you're ready",
#  "on't necessarily expect it to be done before you get back though because i'm just now headin out",
#  'mm so yummy babe ... nice jolt to the suzy',
#  'here are you lover ? i need you ...',
#  'e tried to contact you re your reply to our offer of a video handset? 750 anytime network mins? unlimited text? camcorder? reply or call 08000930705 now',
#  '‘m parked next to a mini!!!! when are you coming in today do you think?',
#  'up',
#  "nyway i'm going shopping on my own now. co my si not done yet. dun disturb u liao.",
#  'y no. in luton 0125698789 ring me if ur around! h*',
#  'ey i am really horny want to chat or see me naked text hot to 69698 text charged at 150pm to unsubscribe text stop 69698',
#  'hy you dint come with us.',
#  'ame. wana plan a trip sometme then',
#  'ot sure yet, still trying to get a hold of him',
#  'r ringtone service ha changed! 25 free credits! go to club4mobiles.com to choose content now! stop? txt club stop to 87070. 150p/wk club4 po box1146 mk45 2wt',
#  'he evo. i just had to download flash. jealous?',
#  'ingtone club: get the uk single chart on your mobile each week and choose any top quality ringtone! this message is free of charge.',
#  "ome to mu, we're sorting out our narcotic situation",
#  'ight ha ended for another day, morning ha come in a special way. may you smile like the sunny ray and leaf your worry at the blue blue bay.',
#  'mv bonus special 500 pound of genuine hmv voucher to be won. just answer 4 easy questions. play now! send hmv to 86688 more info:www.100percent-real.com',
#  'sf i guess, might a well take 1 car',
#  'o objection. my bf not coming.',
#  'hanx...',
#  'ell rob to mack his gf in the theater',
#  "wesome, i'll see you in a bit",
#  'ust sent it. so what type of food do you like?',
#  'll done? all handed in? celebration in full swing yet?',
#  'ou got called a tool?',
#  'en u miss someone, the person is definitely special for u..... but if the person is so special, why to miss them, just keep-in-touch gdeve..',
#  'k. i asked for money how far',
#  'kie...',
#  "eah i think my usual guy's still passed out from last night, if you get ahold of anybody let me know and i'll throw down",
#  ', i might come by tonight then if my class let out early',
#  'k..',
#  'i baby im cruisin with my girl friend what r u up 2? give me a call in and hour at home if thats alright or fone me on this fone now love jenny xxx',
#  'y life mean a lot to me, not because i love my life, but because i love the people in my life, the world call them friends, i call them my world:-).. ge:-)..',
#  'ear,shall mail tonite.busy in the street,shall update you tonite.things are looking ok.varunnathu edukkukayee raksha ollu.but a good one in real sense.',
#  'ey you told your name to gautham ah?',
#  'af u found him? i feel so stupid da v cam wa working.',
#  'ops. 4 got that bit.',
#  're you this much buzy',
#  'accidentally deleted the message. resend please.',
#  "-mobile customer you may now claim your free camera phone upgrade & a pay & go sim card for your loyalty. call on 0845 021 3680.offer end 28thfeb.t&c's apply",
#  "nless it's a situation where you go gurl would be more appropriate",
#  'urt me... tease me... make me cry... but in the end of my life when i die plz keep one rose on my grave and say stupid i miss u.. have a nice day bslvyl',
#  'cant pick the phone right now. pls send a message',
#  "eed a coffee run tomo?can't believe it's that time of week already",
#  'wesome, i remember the last time we got somebody high for the first time with diesel :v',
#  'hit that is really shocking and scary, cant imagine for a second. def up for night out. do u think there is somewhere i could crash for night, save on taxi?',
#  'h and by the way you do have more food in your fridge! want to go out for a meal tonight?',
#  'e is a womdarfull actor',
#  'ms. ac blind date 4u!: rodds1 is 21/m from aberdeen, united kingdom. check him out http://img. sms. ac/w/icmb3cktz8r7!-4 no blind date send hide',
#  'up... from what i remb... i think should be can book...',
#  'o ask if u wana meet up?',
#  "ol yes. our friendship is hanging on a thread cause u won't buy stuff.",
#  'hemob> check out our newest selection of content, games, tones, gossip, babe and sport, keep your mobile fit and funky text wap to 82468',
#  "here are the garage keys? they aren't on the bookshelf",
#  'oday is accept day..u accept me as? brother sister lover dear1 best1 clos1 lvblefrnd jstfrnd cutefrnd lifpartnr belovd swtheart bstfrnd no rply mean enemy',
#  'hink ur smart ? win £200 this week in our weekly quiz, text play to 85222 now!t&cs winnersclub po box 84, m26 3uz. 16+. gbp1.50/week',
#  "e say he'll give me a call when his friend's got the money but that he's definitely buying before the end of the week",
#  'i the way i wa with u 2day, is the normal way&this is the real me. ur unique&i hope i know u 4 the rest of mylife. hope u find wot wa lost.',
#  'ou made my day. do have a great day too.',
#  '.k:)advance happy pongal.',
#  'mmm... guess we can go 4 kb n power yoga... haha, dunno we can tahan power yoga anot... thk got lo oso, forgot liao...',
#  "ot really dude, have no friend i'm afraid :(",
#  'ecember only! had your mobile 11mths+? you are entitled to update to the latest colour camera mobile for free! call the mobile update co free on 08002986906',
#  'offee cake, i guess...',
#  'erry christmas to you too babe, i love ya *kisses*',
#  'ey... why dont we just go watch x men and have lunch... haha',
#  'ud u tell ppl im gona b a bit l8 co 2 bus hav gon past co they were full & im still waitin 4 1. pete x',
#  "hat would be great. we'll be at the guild. could meet on bristol road or somewhere - will get in touch over weekend. our plan take flight! have a good week",
#  'o problem. how are you doing?',
#  'o calls..messages..missed call',
#  'i da:)how is the today class?',
#  "'d say that's a good sign but, well, you know my track record at reading woman",
#  "ool, text me when you're parked",
#  "'m reading the text i just sent you. it meant to be a joke. so read it in that light",
#  '.k:)apo k.good movie.',
#  'aybe i could get book out tomo then return it immediately ..? or something.',
#  'all germany for only 1 penny per minute! call from a fixed line via access number 0844 861 85 85. no prepayment. direct access!',
#  "ny chance you might have had with me evaporated a soon a you violated my privacy by stealing my phone number from your employer's paperwork. not cool at all. please do not contact me again or i will report you to your supervisor.",
#  'alentines day special! win over £1000 in our quiz and take your partner on the trip of a lifetime! send go to 83600 now. 150p/msg rcvd. custcare:08718720201.',
#  'a-daaaaa! i am home babe, are you still up ?',
#  'ool. so how come you havent been wined and dined before?',
#  'ust sleeping..and surfing',
#  "orry, i'll call later",
#  'calling me right? call my hand phone...',
#  "k that's great thanx a lot.",
#  'take it the post ha come then! you must have 1000 of text now! happy reading. my one from wiv hello caroline at the end is my favourite. bless him',
#  'here u been hiding stranger?',
#  'm not interested to do like that.',
#  'y sister cleared two round in birla soft yesterday.',
#  'udnite....tc...practice going on',
#  'is is yijue. i jus saw ur mail. in case huiming havent sent u my num. dis is my num.',
#  'ne small prestige problem now.',
#  'ancy a shag? i do.interested? sextextuk.com txt xxuk suzy to 69876. txts cost 1.50 per msg. tncs on website. x',
#  'ust checking in on you. really do miss seeing jeremiah. do have a great month',
#  "ah can't help you there, i've never had an iphone",
#  "f you're not in my car in an hour and a half i'm going apeshit",
#  "oday is sorry day.! if ever i wa angry with you, if ever i misbehaved or hurt you? plz plz just slap urself bcoz, it ur fault, i'm basically good",
#  'o you guy ever figure out how much we need for alcohol? jay and i are trying to figure out how much we can safely spend on weed',
#  '&lt;#&gt; ish minute wa 5 minute ago. wtf.',
#  'hank you for calling.forgot to say happy onam to you sirji.i am fine here and remembered you when i met an insurance person.meet you in qatar insha allah.rakhesh, ex tata aig who joined tissco,tayseer.',
#  'ongratulations ur awarded 500 of cd voucher or 125gift guaranteed & free entry 2 100 wkly draw txt music to 87066 tncs www.ldew.com1win150ppmx3age16',
#  'r cash-balance is currently 500 pound - to maximize ur cash-in now send cash to 86688 only 150p/msg. cc: 08708800282 hg/suite342/2lands row/w1j6hl',
#  "'m an actor. when i work, i work in the evening and sleep late. since i'm unemployed at the moment, i always sleep late. when you're unemployed, every day is saturday.",
#  'ello! just got here, st andrews-boy it a long way! it cold. i will keep you posted',
#  'a ha cool cool chikku chikku:-):-db-)',
#  'h ok no prob..',
#  "heck audrey's status right now",
#  'usy here. trying to finish for new year. i am looking forward to finally meeting you...',
#  'ood afternoon sunshine! how dawn that day ? are we refreshed and happy to be alive? do we breathe in the air and smile ? i think of you, my love ... a always',
#  'ell i know z will take care of me. so no worries.',
#  'pdate_now - xmas offer! latest motorola, sonyericsson & nokia & free bluetooth! double min & 1000 txt on orange. call mobileupd8 on 08000839402 or call2optout/f4q=',
#  'ere is your discount code rp176781. to stop further message reply stop. www.regalportfolio.co.uk. customer service 08717205546',
#  'at uniform? in where get?',
#  "ool, text me when you're ready",
#  'ello my boytoy ... geeee i miss you already and i just woke up. i wish you were here in bed with me, cuddling me. i love you ...',
#  'will spoil you in bed a well :)',
#  "'m going for bath will msg you next &lt;#&gt; min..",
#  'cant keep talking to people if am not sure i can pay them if they agree to price. so pls tell me what you want to really buy and how much you are willing to pay',
#  'hank for your ringtone order, reference t91. you will be charged gbp 4 per week. you can unsubscribe at anytime by calling customer service on 09057039994',
#  'an you say what happen',
#  "ou could have seen me..i did't recognise you face.:)",
#  "ell there's not a lot of thing happening in lindsay on new year *sighs* some bar in ptbo and the blue heron ha something going",
#  'eep my payasam there if rinu brings',
#  'taught that ranjith sir called me. so only i sm like that. becaus he verifying about project. prabu told today so only pa dont mistake me..',
#  "guess that's why you re worried. you must know that there's a way the body repair itself. and i'm quite sure you shouldn't worry. we'll take it slow. first the tests, they will guide when your ovulation is then just relax. nothing you've said is a reason to worry but i.ll keep on followin you up.",
#  'eah sure, give me a couple minute to track down my wallet',
#  'ey leave it. not a big deal:-) take care.',
#  'ey i will be late ah... meet you at 945+',
#  'ouble min and txts 4 6months free bluetooth on orange. available on sony, nokia motorola phones. call mobileupd8 on 08000839402 or call2optout/n9dx',
#  't took mr owl 3 lick',
#  'ustomer place i will call you.',
#  'm that time you dont like fun',
#  '4mths half price orange line rental & latest camera phone 4 free. had your phone 11mths ? call mobilesdirect free on 08000938767 to update now! or2stoptxt',
#  'up having my lunch buffet now.. u eat already?',
#  'uh so late... fr dinner?',
#  'ey so this sat are we going for the intro pilate only? or the kickboxing too?',
#  'orning only i can ok.',
#  'e i think so. i am in office but my lap is in room i think thats on for the last few days. i didnt shut that down',
#  'ick you up bout 7.30ish? what time are and that going?',
#  'rom here after the performance award is calculated every two month.not for current one month period..',
#  'a actually sleeping and still might when u call back. so a text is gr8. you rock sis. will send u a text wen i wake.',
#  "ou are always putting your business out there. you put picture of your as on facebook. you are one of the most open people i've ever met. why would i think a picture of your room would hurt you, make you feel violated.",
#  'ood evening sir, al salam wahleykkum.sharing a happy news.by the grace of god, i got an offer from tayseer,tissco and i joined.hope you are fine.inshah allah,meet you sometime.rakhesh,visitor from india.',
#  'mmm...k...but i want to change the field quickly da:-)i wanna get system administrator or network administrator..',
#  'ree ringtone text first to 87131 for a poly or text get to 87131 for a true tone! help? 0845 2814032 16 after 1st free, tone are 3x£150pw to e£nd txt stop',
#  'ear how is chechi. did you talk to her',
#  'he hair cream ha not been shipped.',
#  "one of that's happening til you get here though",
#  'ep, the great loxahatchee xmas tree burning of &lt;#&gt; start in an hour',
#  'aha get used to driving to usf man, i know a lot of stoner',
#  "ll wa well until slightly disastrous class this pm with my fav darlings! hope day off ok. coffee wld be good a can't stay late tomorrow. same time + place a always?",
#  'ello! good week? fancy a drink or something later?',
#  'eadin towards busetop',
#  'essage:some text missing* sender:name missing* *number missing *sent:date missing *missing u a lot thats y everything is missing sent via fullonsms.com',
#  'ome by our room at some point so we can iron out the plan for this weekend',
#  'o i want it to be your thing',
#  "kies... i'll go yan jiu too... we can skip ard oso, go cine den go mrt one, blah blah blah...",
#  'ring home some wendy =d',
#  '100 dating service cal;l 09064012103 box334sk38ch',
#  'hatsup there. dont u want to sleep',
#  'lright i have a new goal now',
#  'ree entry into our £250 weekly competition just text the word win to 80086 now. 18 t&c www.txttowin.co.uk',
#  "lright, i'll head out in a few minutes, text me where to meet you",
#  'end a logo 2 ur lover - 2 name joined by a heart. txt love name1 name2 mobno eg love adam eve 07123456789 to 87077 yahoo! pobox36504w45wq txtno 4 no ad 150p',
#  "es:)from last week itself i'm taking live call.",
#  'omeone ha contacted our dating service and entered your phone because they fancy you! to find out who it is call from a landline 09111032124 . pobox12n146tf150p',
#  'iva is in hostel aha:-.',
#  'rgent! your mobile number ha been awarded with a £2000 prize guaranteed. call 09058094455 from land line. claim 3030. valid 12hrs only',
#  'end this to ur friend and receive something about ur voice..... how is my speaking expression? 1.childish 2.naughty 3.sentiment 4.rowdy 5.ful of attitude 6.romantic 7.shy 8.attractive 9.funny &lt;#&gt; .irritating &lt;#&gt; .lovable. reply me..',
#  "k. she'll be ok. i guess",
#  'athi..where are you dear..',
#  'ny pain on urination any thing else?',
#  '7 at esplanade.. do ü mind giving me a lift co i got no car today..',
#  'wnt to buy a bmw car urgently..its vry urgent.but hv a shortage of &lt;#&gt; lacs.there is no source to arng dis amt. &lt;#&gt; lacs..thats my prob',
#  't home watching tv lor.',
#  'oes she usually take fifteen fucking minute to respond to a yes or no question',
#  'ongrats! nokia 3650 video camera phone is your call 09066382422 call cost 150ppm ave call 3mins vary from mobile 16+ close 300603 post bcm4284 ldn wc1n3xx',
#  'ooked ticket for pongal?',
#  "ou available now? i'm like right around hillsborough &amp; &lt;#&gt; th",
#  'he message sent is askin for &lt;#&gt; dollars. shoul i pay &lt;#&gt; or &lt;#&gt; ?',
#  "sk g or iouri, i've told the story like ten time already",
#  'ow long doe applebees fucking take',
#  'i hope u get this txt~journey hasnt been gd,now about 50 min late i think.',
#  'ut i have to. i like to have love and arrange.',
#  'es..he is really great..bhaji told kallis best cricketer after sachin in world:).very tough to get out.',
#  'ou were supposed to wake me up &gt;:(',
#  'ic... i saw him too but i tot he din c me... i found a group liao...',
#  "orry, i'll call later",
#  'ey hey werethe monkeespeople say we monkeyaround! howdy gorgeous, howu doin? foundurself a jobyet sausage?love jen xxx',
#  "orry, my battery died, i can come by but i'm only getting a gram for now, where's your place?",
#  'ell done, blimey, exercise, yeah, i kinda remember wot that is, hmm.',
#  'wont get concentration dear you know you are my mind and everything :-)',
#  'ol ... have you made plan for new years?',
#  '10 min later k...',
#  'anks lotsly!',
#  'hank for this hope you had a good day today',
#  ':)k:)what are detail you want to transfer?acc no enough?',
#  'k i will tell her to stay out. yeah it been tough but we are optimistic thing will improve this month.',
#  "oan for any purpose £500 - £75,000. homeowner + tenant welcome. have you been previously refused? we can still help. call free 0800 1956669 or text back 'help'",
#  'i si. i think ill go make those oreo truffles.',
#  'ook at amy ure a beautiful, intelligent woman and i like u a lot. i know u don\x92t like me like that so don\x92t worry.',
#  "hope you that's the result of being consistently intelligent and kind. start asking him about practicum link and keep your ear open and all the best. ttyl",
#  '1.20 that call cost. which i guess isnt bad. miss ya, need ya, want ya, love ya',
#  'oing thru a very different feeling.wavering decision and coping up with the same is the same individual.time will heal everything i believe.',
#  'here did u go? my phone is gonna die you have to stay in here',
#  'reat. never been better. each day give even more reason to thank god',
#  "pgrdcentre orange customer, you may now claim your free camera phone upgrade for your loyalty. call now on 0207 153 9153. offer end 26th july. t&c's apply. opt-out available",
#  "orry, i'll call later ok bye",
#  'k i am on the way to railway',
#  'reat princess! i love giving and receiving oral. doggy style is my fave position. how about you? i enjoy making love &lt;#&gt; time per night :)',
#  "hey don't put that stuff on the road to keep it from getting slippery over there?",
#  'hen are you going to ride your bike?',
#  "up, no need. i'll jus wait 4 e rain 2 stop.",
#  'here are many company. tell me the language.',
#  'kmail: dear dave this is your final notice to collect your 4* tenerife holiday or #5000 cash award! call 09061743806 from landline. tc sae box326 cw25wx 150ppm',
#  'ow long ha it been since you screamed, princess?',
#  'othing. i meant that once the money enters your account here, the bank will remove it flat rate. someone transfered &lt;#&gt; to my account and &lt;#&gt; dollar got removed. so the bank differ and charge also differ.be sure you trust the 9ja person you are sending account detail to cos...',
#  "ant 2 get laid tonight? want real dogging location sent direct 2 ur mob? join the uk's largest dogging network by txting moan to 69888nyt. ec2a. 31p.msg@150p",
#  "ice line said by a broken heart- plz don't cum 1 more time infront of me... other wise once again i ll trust u... good 9t:)",
#  "k i'm gonna head up to usf in like fifteen minute",
#  'ove you aathi..love u lot..',
#  'ension ah?what machi?any problem?',
#  ", can i pick up another 8th when you're done?",
#  "hen're you guy getting back? g said you were thinking about not staying for mcr",
#  'lmost there, see u in a sec',
#  'o carlos, a few friend are already asking me about you, you working at all this weekend?',
#  'atching tv lor...',
#  'hank you baby! i cant wait to taste the real thing...',
#  'ou should change your fb to jaykwon thuglyfe falconerf',
#  'f we win it really no 1 side for long time.',
#  'ree message activate your 500 free text message by replying to this message with the word free for term & conditions, visit www.07781482378.com',
#  'ear reached railway. what happen to you',
#  'epends on quality. if you want the type i sent boye, faded glory, then about 6. if you want ralphs maybe 2',
#  "think i've fixed it can you send a test message?",
#  "orry man my account's dry or i would, if you want we could trade back half or i could buy some shit with my credit card",
#  'ongrats! 1 year special cinema pas for 2 is yours. call 09061209465 now! c suprman v, matrix3, starwars3, etc all 4 free! bx420-ip4-5we. 150pm. dont miss out!',
#  "orry,in meeting i'll call later",
#  'hat class of &lt;#&gt; reunion?',
#  're you free now?can i call now?',
#  'ot meh... when?',
#  'ope... think i will go for it on monday... sorry i replied so late',
#  'ome of them told accenture is not confirm. is it true.',
#  'ate jackson rec center before 7ish, right?',
#  'ear i have reache room',
#  'ighting with the world is easy, u either win or lose bt fightng with some1 who is close to u is dificult if u lose - u lose if u win - u still lose.',
#  'hen can ü come out?',
#  'heck with nuerologist.',
#  'olnice. i went from a fish to ..water.?',
#  "+123 congratulation - in this week's competition draw u have won the £1450 prize to claim just call 09050002311 b4280703. t&cs/stop sm 08718727868. over 18 only 150ppm",
#  "o it's waiting in e car dat's bored wat. co wait outside got nothing 2 do. at home can do my stuff or watch tv wat.",
#  'aybe westshore or hyde park village, the place near my house?',
#  "ou should know now. so how's anthony. are you bringing money. i've school fee to pay and rent and stuff like that. thats why i need your help. a friend in need....|",
#  "hat's the significance?",
#  'our opinion about me? 1. over 2. jada 3. kusruthi 4. lovable 5. silent 6. spl character 7. not matured 8. stylish 9. simple pls reply..',
#  "8 at the latest, g's still there if you can scrounge up some ammo and want to give the new ak a try",
#  "rabha..i'm soryda..realy..frm heart i'm sory",
#  'ol ok your forgiven :)',
#  'o..jst change tat only..',
#  'ou are guaranteed the latest nokia phone, a 40gb ipod mp3 player or a £500 prize! txt word: collect to no: 83355! ibhltd ldnw15h 150p/mtmsgrcvd18+',
#  ':)no competition for him.',
#  'oltblue tone for 150p reply poly# or mono# eg poly3 1. cha cha slide 2. yeah 3. slow jamz 6. toxic 8. come with me or stop 4 more tone txt more',
#  'our credit have been topped up for http://www.bubbletext.com your renewal pin is tgxxrz',
#  'hat way transport is less problematic than on sat night. by the way, if u want to ask n to join my bday, feel free. but need to know definite no a booking on fri.',
#  "sually the person is unconscious that's in child but in adult they may just behave abnormally. i.ll call you now",
#  "ut that's on ebay it might be less elsewhere.",
#  'hall i come to get pickle',
#  'ere gonna go get some taco',
#  "hat's very rude, you on campus?",
#  'rgent!: your mobile no. wa awarded a £2,000 bonus caller prize on 02/09/03! this is our 2nd attempt to contact you! call 0871-872-9755 box95qu',
#  "i i won't b ard 4 christmas. but do enjoy n merry x'mas.",
#  "oday's offer! claim ur £150 worth of discount vouchers! text yes to 85023 now! savamob, member offer mobile! t c 08717898035. £3.00 sub. 16 . unsub reply x",
#  'es! how is a pretty lady like you single?',
#  'ou will recieve your tone within the next 24hrs. for term and condition please see channel u teletext pg 750',
#  "ay say that you're a double-faggot",
#  'rivate! your 2003 account statement for 07815296484 show 800 un-redeemed s.i.m. points. call 08718738001 identifier code 41782 expires 18/11/04',
#  'hat today-sunday..sunday is holiday..so no work..',
#  'udnite....tc...practice going on',
#  "'ll be late...",
#  "'ve not called you in a while. this is hoping it wa l8r malaria and that you know that we miss you guys. i miss ban big, so pls give her my love especially. have a great day.",
#  'ood afternoon, my love! how go that day ? i hope maybe you got some lead on a job. i think of you, boytoy and send you a passionate kiss from across the sea',
#  'robably gonna be here for a while, see you later tonight &lt;)',
#  "r maybe my fat finger just press all these button and it doesn't know what to do.",
#  'mmmmmaah many many happy return of d day my dear sweet heart.. happy birthday dear',
#  'am in tirupur da, once you started from office call me.',
#  'rom www.applausestore.com monthlysubscription@50p/msg max6/month t&csc web age16 2stop txt stop',
#  "famous quote : when you develop the ability to listen to 'anything' unconditionally without losing your temper or self confidence, it mean you are ......... 'married'",
#  'ut am going to college pa. what to do. are else ill come there it self. pa.',
#  '4 oclock at mine. just to bash out a flat plan.',
#  "his girl doe not stay in bed. this girl doesn't need recovery time. id rather pas out while having fun then be cooped up in bed",
#  'hen any special there?',
#  "know but you need to get hotel now. i just got my invitation but i had to apologise. cali is to sweet for me to come to some english bloke's weddin",
#  'orry that took so long, omw now',
#  'ait &lt;#&gt; min..',
#  "k give me 5 minute i think i see her. btw you're my alibi. you were cutting my hair the whole time.",
#  'magine you finally get to sink into that bath after i have put you through your paces, maybe even having you eat me for a while before i left ... but also imagine the feel of that cage on your cock surrounded by the bath water, reminding you always who owns you ... enjoy, my cuck',
#  "urry up, i've been weed-deficient for like three day",
#  "ure, if i get an acknowledgement from you that it's astoundingly tactless and generally faggy to demand a blood oath fo",
#  "k. every night take a warm bath drink a cup of milk and you'll see a work of magic. you still need to loose weight. just so that you know",
#  '‘ll have a look at the frying pan in case it‘s cheap or a book perhaps. no that‘s silly a frying pan isn‘t likely to be a book',
# ...
#  'ahaha..use your brain dear',
#  'ey. you got any mail?',
#  'orry light turned green, i meant another friend wanted &lt;#&gt; worth but he may not be around',
#  'hank for yesterday sir. you have been wonderful. hope you enjoyed the burial. mojibiola',
#  'have a secret admirer. reveal who think u r so special. call 09065174042. to opt out reply reveal stop. 1.50 per msg recd. cust care 07821230901',
#  'i mate it rv did u hav a nice hol just a message 3 say hello coz haven\x92t sent u 1 in age started driving so stay off roads!rvx',
#  'ear voucher holder, to claim this week offer, at you pc please go to http://www.e-tlp.co.uk/expressoffer ts&cs apply. to stop texts, txt stop to 80062',
#  "hank you so much. when we skyped wit kz and sura, we didnt get the pleasure of your company. hope you are good. we've given you ultimatum oh! we are countin down to aburo. enjoy! this is the message i sent day ago",
#  'urely result will offer:)',
#  'ood morning my dear........... have a great &amp; successful day.',
#  'o you want 750 anytime any network min 150 text and a new video phone for only five pound per week call 08002888812 or reply for delivery tomorrow',
#  "ir, i have been late in paying rent for the past few month and had to pay a $ &lt;#&gt; charge. i felt it would be inconsiderate of me to nag about something you give at great cost to yourself and that's why i didnt speak up. i however am in a recession and wont be able to pay the charge this month hence my askin well ahead of month's end. can you please help. thanks",
#  'e tried to contact you re our offer of new video phone 750 anytime any network min half price rental camcorder call 08000930705 or reply for delivery wed',
#  'ast chance 2 claim ur £150 worth of discount vouchers-text yes to 85023 now!savamob-member offer mobile t c 08717898035. £3.00 sub. 16 . remove txt x or stop',
#  'luv u soo much u don\x92t understand how special u r 2 me ring u 2morrow luv u xxx',
#  "l send me a comprehensive mail about who i'm paying, when and how much.",
#  "ur prashanthettan's mother passed away last night. pray for her and family.",
#  'rgent! call 09066350750 from your landline. your complimentary 4* ibiza holiday or 10,000 cash await collection sae t&cs po box 434 sk3 8wp 150 ppm 18+',
#  '.k:)when are you going?',
#  "eanwhile in the shit suite: xavier decided to give u &lt;#&gt; second of warning that samantha wa coming over and is playing jay's guitar to impress her or some shit. also i don't think doug realizes i don't live here anymore",
#  "y stomach ha been thru so much trauma i swear i just can't eat. i better lose weight.",
#  'am in office:)whats the matter..msg me now.i will call you at break:).',
#  "eah there's barely enough room for the two of us, x ha too many fucking shoes. sorry man, see you later",
#  "oday's offer! claim ur £150 worth of discount vouchers! text yes to 85023 now! savamob, member offer mobile! t c 08717898035. £3.00 sub. 16 . unsub reply x",
#  'reach orchard already? u wan 2 go buy ticket first?',
#  'am real, baby! i want to bring out your inner tigress...',
#  'o da if you run that it activate the full version da.',
#  'h poor baby!hope urfeeling bettersn luv! probthat overdose of work hey go careful spk 2 u sn lot of lovejen xxx.',
#  "top the story. i've told him i've returned it and he's saying i should not re order it.",
#  'alk sexy!! make new friend or fall in love in the world most discreet text dating service. just text vip to 83110 and see who you could meet.',
#  'oing to take your babe out ?',
#  'ai ana tomarrow am coming on morning. &lt;decimal&gt; ill be there in sathy then we ll go to rto office. reply me after came to home.',
#  'poon it is then okay?',
#  'id he just say somebody is named tampa',
#  'n work now. going have in few min.',
#  'our brother is a genius',
#  "orry, i guess whenever i can get a hold of my connections, maybe an hour or two? i'll text you",
#  'id u find out what time the bus is at coz i need to sort some stuff out.',
#  'ude ive been seeing a lotta corvette lately',
#  'ongratulations ur awarded either a yr supply of cd from virgin record or a mystery gift guaranteed call 09061104283 ts&cs www.smsco.net £1.50pm approx 3mins',
#  "ame here, but i consider wall and bunker and shit important just because i never play on peaceful but i guess your place is high enough that it don't matter",
#  'rivate! your 2003 account statement for 07808 xxxxxx show 800 un-redeemed s. i. m. points. call 08719899217 identifier code: 41685 expires 07/11/04',
#  'ello. we need some posh bird and chap to user trial prod for champneys. can i put you down? i need your address and dob asap. ta r',
#  'hat do u want for xmas? how about 100 free text message & a new video phone with half price line rental? call free now on 0800 0721072 to find out more!',
#  'ell am officially in a philosophical hole, so if u wanna call am at home ready to be saved!',
#  't going good...no problem..but still need little experience to understand american customer voice...',
#  "'ll text you when i drop x off",
#  "gh it been a long day. i'm exhausted. just want to cuddle up and take a nap",
#  'alk with yourself atleast once in a day...!!! otherwise you will miss your best friend in this world...!!! -shakespeare- shesil &lt;#&gt;',
#  'hop till u drop, is it you, either 10k, 5k, £500 cash or £100 travel voucher, call now, 09064011000. ntt po box cr01327bt fixedline cost 150ppm mobile vary',
#  're you in castor? you need to see something',
#  'unshine quiz wkly q! win a top sony dvd player if u know which country liverpool played in mid week? txt ansr to 82277. £1.50 sp:tyrone',
#  'have a secret admirer who is looking 2 make contact with u-find out who they r*reveal who think ur so special-call on 09058094565',
#  'have a secret admirer who is looking 2 make contact with u-find out who they r*reveal who think ur so special-call on 09065171142-stopsms-08',
#  'eminder: you have not downloaded the content you have already paid for. goto http://doit. mymoby. tv/ to collect your content.',
#  "ee, i knew giving you a break a few time woul lead to you always wanting to miss curfew. i wa gonna gibe you 'til one, but a midnight movie is not gonna get out til after 2. you need to come home. you need to getsleep and, if anything, you need to b studdying ear training.",
#  'love to give massages. i use lot of baby oil... what is your fave position?',
#  'ude we should go sup again',
#  'oyyooo u know how to change permission for a drive in mac. my usb flash drive',
#  'ibbs unsold.mike hussey',
#  'like to talk pa but am not able to. i dont know y.',
#  "dun cut too short leh. u dun like ah? she failed. she's quite sad.",
#  'ou unbelievable faglord',
#  'ife.how she knew the time of murder exactly',
#  'hy do you ask princess?',
#  'am great princess! what are you thinking about me? :)',
#  'utter. cutter. ctter. cttergg. cttargg. ctargg. ctagg. ie you',
#  "t's ok i noe u're busy but i'm really too bored so i msg u. i oso dunno wat colour she choose 4 me one.",
#  "oesn't g have class early tomorrow and thus shouldn't be trying to smoke at &lt;#&gt;",
#  'uperb thought- "be grateful that u dont have everything u want. that mean u still have an opportunity to be happier tomorrow than u are today.":-)',
#  'ope you are having a good week. just checking in',
#  "'m used to it. i just hope my agent don't drop me since i've only booked a few thing this year. this whole me in boston, them in nyc wa an experiment.",
#  "hursday night? yeah, sure thing, we'll work it out then",
#  'our free ringtone is waiting to be collected. simply text the password "mix" to 85069 to verify. get usher and britney. fml, po box 5249, mk17 92h. 450ppw 16',
#  'robably money worries. thing are coming due and i have several outstanding invoice for work i did two and three month ago.',
#  'ow is it possible to teach you. and where.',
#  'wonder if your phone battery went dead ? i had to tell you, i love you babe',
#  "ovely smell on this bus and it ain't tobacco...",
#  "e're all getting worried over here, derek and taylor have already assumed the worst",
#  "ey what's up charles sorry about the late reply.",
#  'll the lastest from stereophonics, marley, dizzee racal, libertine and the strokes! win nookii game with flirt!! click themob wap bookmark or text wap to 82468',
#  '.ll give her once i have it. plus she said grinule greet you whenever we speak',
#  'hite fudge oreo are in store',
#  'anuary male sale! hot gay chat now cheaper, call 08709222922. national rate from 1.5p/min cheap to 7.8p/min peak! to stop text call 08712460324 (10p/min)',
#  "y love ! how come it took you so long to leave for zaher's? i got your word on ym and wa happy to see them but wa sad you had left. i miss you",
#  'am sorry it hurt you.',
#  "an't. i feel nauseous. i'm so pissed. i didn't eat any sweet all week cause today i wa planning to pig out. i wa dieting all week. and now i'm not hungry :/",
#  'k lor but not too early. me still having project meeting now.',
#  'all me da, i am waiting for your call.',
#  'could ask carlos if we could get more if anybody else can chip in',
#  'a actually about to send you a reminder today. have a wonderful weekend',
#  "hen people see my msgs, they think iam addicted to msging... they are wrong, bcoz they don\\'t know that iam addicted to my sweet friends..!! bslvyl",
#  'ey you gave them your photo when you registered for driving ah? tmr wanna meet at yck?',
#  'ont talk to him ever ok it my word.',
#  'hen u wana see it then',
#  "n ma way to school. can you pls send me ashley's number",
#  't shall be fine. i have avalarr now. will hollalater',
#  "he went to attend another two round today..but still did't reach home..",
#  'ctually i deleted my old website..now i m blogging at magicalsongs.blogspot.com',
#  ', wait chikku..il send aftr &lt;#&gt; min',
#  "ut i'm on a diet. and i ate 1 too many slice of pizza yesterday. ugh i'm always on a diet.",
#  ':)i will give my kvb acc details:)',
#  'h all have to come ah?',
#  'oney!!! you r a lucky winner ! 2 claim your prize text money 2 88600 over £1million to give away ! ppt150x3+normal text rate box403 w1t1jy',
#  "'m really sorry i won't b able 2 do this friday.hope u can find an alternative.hope yr term's going ok:-)",
#  'ongratulations ore mo owo re wa. enjoy it and i wish you many happy moment to and fro wherever you go',
#  'o do you have samus shoulder yet',
#  "hat time you think you'll have it? need to know when i should be near campus",
#  'ear matthew please call 09063440451 from a landline, your complimentary 4*lux tenerife holiday or £1000 cash await collection. ppm150 sae t&cs box334 sk38xh.',
#  'hen dun wear jean lor...',
#  'ince when, which side, any fever, any vomitin.',
#  ':)k.are you in college?',
#  'rgent! call 09061749602 from landline. your complimentary 4* tenerife holiday or £10,000 cash await collection sae t&cs box 528 hp20 1yf 150ppm 18+',
#  'etter. made up for friday and stuffed myself like a pig yesterday. now i feel bleh. but at least it not writhing pain kind of bleh.',
#  "o we sell it all so we'll have ton if coins. then sell our coin to someone thru paypal. voila! money back in life pockets:)",
#  'heyre doing it to lot of places. only hospital and medical place are safe.',
#  'ow about getting in touch with folk waiting for company? just txt back your name and age to opt in! enjoy the community (150p/sms)',
#  "nd also i've sorta blown him off a couple time recently so id rather not text him out of the blue looking for weed",
#  'sent my score to sophas and i had to do secondary application for a few schools. i think if you are thinking of applying, do a research on cost also. contact joke ogunrinde, her school is one me the less expensive one',
#  'cant wait to see you! how were the photo were useful? :)',
#  'r cash-balance is currently 500 pound - to maximize ur cash-in now send go to 86688 only 150p/msg. cc: 08718720201 po box 114/14 tcr/w1',
#  'ey i booked the kb on sat already... what other lesson are we going for ah? keep your sat night free we need to meet and confirm our lodging',
#  'hk in ur belovd m dict',
#  's that what time you want me to come?',
#  "wesome, lemme know whenever you're around",
#  'hb b ok lor... thanx...',
#  'eautiful truth against gravity.. read carefully: "our heart feel light when someone is in it.. but it feel very heavy when someone leaf it.." good night',
#  "lso remember to get dobby's bowl from your car",
#  'ilthy story and girl waiting for your',
#  "orry i now then c ur msg... yar lor so poor thing... but only 4 one night... tmr u'll have a brand new room 2 sleep in...",
#  "ove isn't a decision, it's a feeling. if we could decide who to love, then, life would be much simpler, but then less magical",
#  'elp apparently he retired',
#  "y sort code is and acc no is . the bank is natwest. can you reply to confirm i've sent this to the right person!",
#  'here @',
#  "sure u can't take any sick time?",
#  'rgent! we are trying to contact u. today draw show that you have won a £800 prize guaranteed. call 09050001808 from land line. claim m95. valid12hrs only',
#  'atching cartoon, listening music &amp; at eve had to go temple &amp; church.. what about u?',
#  'o chad which gymnastics class do you wanna take? the site say christian class is full..',
#  're you this much buzy',
#  'r better still can you catch her and let ask her if she can sell &lt;#&gt; for me.',
#  'am not sure about night menu. . . i know only about noon menu',
#  'hat do u want when i come back?.a beautiful necklace a a token of my heart for you.thats what i will give but only to my wife of my liking.be that and see..no one can give you that.dont call me.i will wait till i come.',
#  're you willing to go for aptitude class.',
#  't wont b until 2.15 a trying 2 sort house out, is that ok?',
#  'ar lor he wan 2 go c horse racing today mah, so eat earlier lor. i ate chicken rice. u?',
#  'aha awesome, omw back now then',
#  'up i thk so until e shop close lor.',
#  'hat is your account number?',
#  'h u send wrongly lar...',
#  'ey no i ad a crap nite wa borin without ya 2 boggy with me u boring biatch! thanx but u wait til nxt time il ave ya',
#  'k i shall talk to him',
#  'ont hesitate. you know this is the second time she ha had weakness like that. so keep i notebook of what she eat and did the day before or if anything changed the day before so that we can be sure it nothing',
#  'ey you can pay. with salary de. only &lt;#&gt; .',
#  'nother month. i need chocolate weed and alcohol.',
#  'f he started searching he will get job in few days.he have great potential and talent.',
#  'eckon need to be in town by eightish to walk from * carpark.',
#  'ongrats! 2 mobile 3g videophones r yours. call 09063458130 now! videochat wid your mates, play java games, dload polyph music, noline rentl.',
#  'ook at the fuckin time. what the fuck you think is up',
#  'o guess what i just dropped',
#  "arlos say he'll be at mu in &lt;#&gt; minute",
#  "'m in office now . i will call you &lt;#&gt; min:)",
#  "eeee ... i miss you already, you know ? your all i can think about. fuck, i can't wait till next year when we will be together ... *loving kiss*",
#  'un ah.the ubi one say if ü wan call by tomorrow.call 67441233 look for irene.ere only got bus8,22,65,61,66,382. ubi cres,ubi tech park.6ph for 1st 5wkg days.èn',
#  'gh. gotta drive back to sd from la. my butt is sore.',
#  '26th of july',
#  'i im having the most relaxing time ever! we have to get up at 7am every day! wa the party good the other night? i get home tomorrow at 5ish.',
#  'p to ü... ü wan come then come lor... but i din c any stripe skirt...',
#  'he xmas story is peace.. the xmas msg is love.. the xmas miracle is jesus.. hav a blessed month ahead &amp; wish u merry xmas...',
#  "can't, i don't have her number!",
#  "hange again... it's e one next to escalator...",
#  "etunde i'm in class can you not run water on it to make it ok. pls now.",
#  'ot a lot ha happened here. feel very quiet. beth is at her aunt and charlie is working lots. just me and helen in at the mo. how have you been?',
#  'hen ü wait 4 me at bus stop aft ur lect lar. if i dun c ü then i go get my car then come back n pick ü.',
#  ...]

# %%
# shortcut for the upper code
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
words = []
for sent in corpus:
    sent_token = sent_tokenize(sent)
    words.append(simple_preprocess(sent))

# %%
words
# Out:
# [['until',
#   'jurong',
#   'point',
#   'crazy',
#   'available',
#   'only',
#   'in',
#   'bugis',
#   'great',
#   'world',
#   'la',
#   'buffet',
#   'cine',
#   'there',
#   'got',
#   'amore',
#   'wat'],
#  ['lar', 'joking', 'wif', 'oni'],
#  ['ree',
#   'entry',
#   'in',
#   'wkly',
#   'comp',
#   'to',
#   'win',
#   'fa',
#   'cup',
#   'final',
#   'tkts',
#   'st',
#   'may',
#   'text',
#   'fa',
#   'to',
#   'to',
#   'receive',
#   'entry',
#   'question',
#   'std',
#   'txt',
#   'rate',
#   'apply',
#   'over'],
#  ['dun', 'say', 'so', 'early', 'hor', 'already', 'then', 'say'],
#  ['ah',
#   'don',
#   'think',
#   'he',
#   'go',
#   'to',
#   'usf',
#   'he',
#   'life',
#   'around',
#   'here',
#   'though'],
#  ['reemsg',
#   'hey',
#   'there',
#   'darling',
#   'it',
#   'been',
#   'week',
#   'now',
#   'and',
#   'no',
#   'word',
#   'back',
#   'like',
#   'some',
#   'fun',
#   'you',
#   'up',
#   'for',
#   'it',
#   'still',
#   'tb',
#   'ok',
#   'xxx',
#   'std',
#   'chgs',
#   'to',
#   'send',
#   'to',
#   'rcv'],
#  ['ven',
#   'my',
#   'brother',
#   'is',
#   'not',
#   'like',
#   'to',
#   'speak',
#   'with',
#   'me',
#   'they',
#   'treat',
#   'me',
#   'like',
#   'aid',
#   'patent'],
#  ['per',
#   'your',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'ha',
#   'been',
#   'set',
#   'your',
#   'callertune',
#   'for',
#   'all',
#   'callers',
#   'press',
#   'to',
#   'copy',
#   'your',
#   'friend',
#   'callertune'],
#  ['inner',
#   'valued',
#   'network',
#   'customer',
#   'you',
#   'have',
#   'been',
#   'selected',
#   'to',
#   'receivea',
#   'prize',
#   'reward',
#   'to',
#   'claim',
#   'call',
#   'claim',
#   'code',
#   'kl',
#   'valid',
#   'hour',
#   'only'],
#  ['ad',
#   'your',
#   'mobile',
#   'month',
#   'or',
#   'more',
#   'entitled',
#   'to',
#   'update',
#   'to',
#   'the',
#   'latest',
#   'colour',
#   'mobile',
#   'with',
#   'camera',
#   'for',
#   'free',
#   'call',
#   'the',
#   'mobile',
#   'update',
#   'co',
#   'free',
#   'on'],
#  ['gonna',
#   'be',
#   'home',
#   'soon',
#   'and',
#   'don',
#   'want',
#   'to',
#   'talk',
#   'about',
#   'this',
#   'stuff',
#   'anymore',
#   'tonight',
#   've',
#   'cried',
#   'enough',
#   'today'],
#  ['ix',
#   'chance',
#   'to',
#   'win',
#   'cash',
#   'from',
#   'to',
#   'pound',
#   'txt',
#   'csh',
#   'and',
#   'send',
#   'to',
#   'cost',
#   'day',
#   'days',
#   'tsandcs',
#   'apply',
#   'reply',
#   'hl',
#   'info'],
#  ['rgent',
#   'you',
#   'have',
#   'won',
#   'week',
#   'free',
#   'membership',
#   'in',
#   'our',
#   'prize',
#   'jackpot',
#   'txt',
#   'the',
#   'word',
#   'claim',
#   'to',
#   'no',
#   'www',
#   'dbuk',
#   'net',
#   'lccltd',
#   'pobox',
#   'ldnw',
#   'rw'],
#  ['ve',
#   'been',
#   'searching',
#   'for',
#   'the',
#   'right',
#   'word',
#   'to',
#   'thank',
#   'you',
#   'for',
#   'this',
#   'breather',
#   'promise',
#   'wont',
#   'take',
#   'your',
#   'help',
#   'for',
#   'granted',
#   'and',
#   'will',
#   'fulfil',
#   'my',
#   'promise',
#   'you',
#   'have',
#   'been',
#   'wonderful',
#   'and',
#   'blessing',
#   'at',
#   'all',
#   'times'],
#  ['have', 'date', 'on', 'sunday', 'with', 'will'],
#  ['to',
#   'use',
#   'your',
#   'credit',
#   'click',
#   'the',
#   'wap',
#   'link',
#   'in',
#   'the',
#   'next',
#   'txt',
#   'message',
#   'or',
#   'click',
#   'here',
#   'http',
#   'wap',
#   'com',
#   'qjkgighjjgcbl'],
#  ['watching', 'here'],
#  ['remember',
#   'how',
#   'spell',
#   'his',
#   'name',
#   'yes',
#   'did',
#   'he',
#   'naughty',
#   'make',
#   'until',
#   'wet'],
#  ['ine',
#   'if',
#   'that',
#   'the',
#   'way',
#   'feel',
#   'that',
#   'the',
#   'way',
#   'it',
#   'gota'],
#  ['ngland',
#   'macedonia',
#   'dont',
#   'miss',
#   'the',
#   'goals',
#   'team',
#   'news',
#   'txt',
#   'ur',
#   'national',
#   'team',
#   'to',
#   'eg',
#   'england',
#   'to',
#   'try',
#   'wales',
#   'scotland',
#   'txt',
#   'poboxox',
#   'wq'],
#  ['that', 'seriously', 'how', 'you', 'spell', 'his', 'name'],
#  ['going', 'to', 'try', 'for', 'month', 'ha', 'ha', 'only', 'joking'],
#  ['pay', 'first', 'lar', 'then', 'when', 'is', 'da', 'stock', 'comin'],
#  ['ft',
#   'finish',
#   'my',
#   'lunch',
#   'then',
#   'go',
#   'str',
#   'down',
#   'lor',
#   'ard',
#   'smth',
#   'lor',
#   'finish',
#   'ur',
#   'lunch',
#   'already'],
#  ['fffffffff',
#   'alright',
#   'no',
#   'way',
#   'can',
#   'meet',
#   'up',
#   'with',
#   'you',
#   'sooner'],
#  ['ust',
#   'forced',
#   'myself',
#   'to',
#   'eat',
#   'slice',
#   'really',
#   'not',
#   'hungry',
#   'tho',
#   'this',
#   'sucks',
#   'mark',
#   'is',
#   'getting',
#   'worried',
#   'he',
#   'know',
#   'sick',
#   'when',
#   'turn',
#   'down',
#   'pizza',
#   'lol'],
#  ['ol', 'your', 'always', 'so', 'convincing'],
#  ['id',
#   'you',
#   'catch',
#   'the',
#   'bus',
#   'are',
#   'you',
#   'frying',
#   'an',
#   'egg',
#   'did',
#   'you',
#   'make',
#   'tea',
#   'are',
#   'you',
#   'eating',
#   'your',
#   'mom',
#   'left',
#   'over',
#   'dinner',
#   'do',
#   'you',
#   'feel',
#   'my',
#   'love'],
#  ['back',
#   'amp',
#   'we',
#   're',
#   'packing',
#   'the',
#   'car',
#   'now',
#   'll',
#   'let',
#   'you',
#   'know',
#   'if',
#   'there',
#   'room'],
#  ['hhh',
#   'work',
#   'vaguely',
#   'remember',
#   'that',
#   'what',
#   'doe',
#   'it',
#   'feel',
#   'like',
#   'lol'],
#  ['ait',
#   'that',
#   'still',
#   'not',
#   'all',
#   'that',
#   'clear',
#   'were',
#   'you',
#   'not',
#   'sure',
#   'about',
#   'me',
#   'being',
#   'sarcastic',
#   'or',
#   'that',
#   'that',
#   'why',
#   'doesn',
#   'want',
#   'to',
#   'live',
#   'with'],
#  ['eah',
#   'he',
#   'got',
#   'in',
#   'at',
#   'and',
#   'wa',
#   'apologetic',
#   'had',
#   'fallen',
#   'out',
#   'and',
#   'she',
#   'wa',
#   'actin',
#   'like',
#   'spoilt',
#   'child',
#   'and',
#   'he',
#   'got',
#   'caught',
#   'up',
#   'in',
#   'that',
#   'till',
#   'but',
#   'we',
#   'won',
#   'go',
#   'there',
#   'not',
#   'doing',
#   'too',
#   'badly',
#   'cheers',
#   'you'],
#  ['tell', 'me', 'anything', 'about', 'you'],
#  ['or',
#   'fear',
#   'of',
#   'fainting',
#   'with',
#   'the',
#   'of',
#   'all',
#   'that',
#   'housework',
#   'you',
#   'just',
#   'did',
#   'quick',
#   'have',
#   'cuppa'],
#  ['hank',
#   'for',
#   'your',
#   'subscription',
#   'to',
#   'ringtone',
#   'uk',
#   'your',
#   'mobile',
#   'will',
#   'be',
#   'charged',
#   'month',
#   'please',
#   'confirm',
#   'by',
#   'replying',
#   'yes',
#   'or',
#   'no',
#   'if',
#   'you',
#   'reply',
#   'no',
#   'you',
#   'will',
#   'not',
#   'be',
#   'charged'],
#  ['up',
#   'ok',
#   'go',
#   'home',
#   'look',
#   'at',
#   'the',
#   'timing',
#   'then',
#   'msg',
#   'again',
#   'xuhui',
#   'going',
#   'to',
#   'learn',
#   'on',
#   'nd',
#   'may',
#   'too',
#   'but',
#   'her',
#   'lesson',
#   'is',
#   'at',
#   'am'],
#  ['ops', 'll', 'let', 'you', 'know', 'when', 'my', 'roommate', 'done'],
#  ['see', 'the', 'letter', 'on', 'my', 'car'],
#  ['nything', 'lor', 'decide'],
#  ['ello',
#   'how',
#   'you',
#   'and',
#   'how',
#   'did',
#   'saturday',
#   'go',
#   'wa',
#   'just',
#   'texting',
#   'to',
#   'see',
#   'if',
#   'you',
#   'decided',
#   'to',
#   'do',
#   'anything',
#   'tomo',
#   'not',
#   'that',
#   'trying',
#   'to',
#   'invite',
#   'myself',
#   'or',
#   'anything'],
#  ['go',
#   'ahead',
#   'with',
#   'watts',
#   'just',
#   'wanted',
#   'to',
#   'be',
#   'sure',
#   'do',
#   'have',
#   'great',
#   'weekend',
#   'abiola'],
#  ['id',
#   'forget',
#   'to',
#   'tell',
#   'you',
#   'want',
#   'you',
#   'need',
#   'you',
#   'crave',
#   'you',
#   'but',
#   'most',
#   'of',
#   'all',
#   'love',
#   'you',
#   'my',
#   'sweet',
#   'arabian',
#   'steed',
#   'mmmmmm',
#   'yummy'],
#  ['rodger',
#   'burn',
#   'msg',
#   'we',
#   'tried',
#   'to',
#   'call',
#   'you',
#   're',
#   'your',
#   'reply',
#   'to',
#   'our',
#   'sm',
#   'for',
#   'free',
#   'nokia',
#   'mobile',
#   'free',
#   'camcorder',
#   'please',
#   'call',
#   'now',
#   'for',
#   'delivery',
#   'tomorrow'],
#  ['ho', 'are', 'you', 'seeing'],
#  ['reat',
#   'hope',
#   'you',
#   'like',
#   'your',
#   'man',
#   'well',
#   'endowed',
#   'am',
#   'lt',
#   'gt',
#   'inches'],
#  ['calls', 'messages', 'missed', 'call'],
#  ['idn', 'you', 'get', 'hep', 'immunisation', 'in', 'nigeria'],
#  ['air', 'enough', 'anything', 'going', 'on'],
#  ['eah',
#   'hopefully',
#   'if',
#   'tyler',
#   'can',
#   'do',
#   'it',
#   'could',
#   'maybe',
#   'ask',
#   'around',
#   'bit'],
#  ['don',
#   'know',
#   'how',
#   'stubborn',
#   'am',
#   'didn',
#   'even',
#   'want',
#   'to',
#   'go',
#   'to',
#   'the',
#   'hospital',
#   'kept',
#   'telling',
#   'mark',
#   'not',
#   'weak',
#   'sucker',
#   'hospital',
#   'are',
#   'for',
#   'weak',
#   'suckers'],
#  ['hat',
#   'you',
#   'thinked',
#   'about',
#   'me',
#   'first',
#   'time',
#   'you',
#   'saw',
#   'me',
#   'in',
#   'class'],
#  ['gram',
#   'usually',
#   'run',
#   'like',
#   'lt',
#   'gt',
#   'half',
#   'eighth',
#   'is',
#   'smarter',
#   'though',
#   'and',
#   'get',
#   'you',
#   'almost',
#   'whole',
#   'second',
#   'gram',
#   'for',
#   'lt',
#   'gt'],
#  ['fyi',
#   'ha',
#   'ride',
#   'early',
#   'tomorrow',
#   'morning',
#   'but',
#   'he',
#   'crashing',
#   'at',
#   'our',
#   'place',
#   'tonight'],
#  ['ow',
#   'never',
#   'realized',
#   'that',
#   'you',
#   'were',
#   'so',
#   'embarassed',
#   'by',
#   'your',
#   'accomodations',
#   'thought',
#   'you',
#   'liked',
#   'it',
#   'since',
#   'wa',
#   'doing',
#   'the',
#   'best',
#   'could',
#   'and',
#   'you',
#   'always',
#   'seemed',
#   'so',
#   'happy',
#   'about',
#   'the',
#   'cave',
#   'sorry',
#   'didn',
#   'and',
#   'don',
#   'have',
#   'more',
#   'to',
#   'give',
#   'sorry',
#   'offered',
#   'sorry',
#   'your',
#   'room',
#   'wa',
#   'so',
#   'embarassing'],
#  ['ms',
#   'ac',
#   'sptv',
#   'the',
#   'new',
#   'jersey',
#   'devil',
#   'and',
#   'the',
#   'detroit',
#   'red',
#   'wing',
#   'play',
#   'ice',
#   'hockey',
#   'correct',
#   'or',
#   'incorrect',
#   'end',
#   'reply',
#   'end',
#   'sptv'],
#  ['you',
#   'know',
#   'what',
#   'mallika',
#   'sherawat',
#   'did',
#   'yesterday',
#   'find',
#   'out',
#   'now',
#   'lt',
#   'url',
#   'gt'],
#  ['ongrats',
#   'year',
#   'special',
#   'cinema',
#   'pas',
#   'for',
#   'is',
#   'yours',
#   'call',
#   'now',
#   'suprman',
#   'matrix',
#   'starwars',
#   'etc',
#   'all',
#   'free',
#   'bx',
#   'ip',
#   'we',
#   'pm',
#   'dont',
#   'miss',
#   'out'],
#  ['orry', 'll', 'call', 'later', 'in', 'meeting'],
#  ['ell', 'where', 'you', 'reached'],
#  ['es', 'gauti', 'and', 'sehwag', 'out', 'of', 'odi', 'series'],
#  ['our',
#   'gonna',
#   'have',
#   'to',
#   'pick',
#   'up',
#   'burger',
#   'for',
#   'yourself',
#   'on',
#   'your',
#   'way',
#   'home',
#   'can',
#   'even',
#   'move',
#   'pain',
#   'is',
#   'killing',
#   'me'],
#  ['ha', 'ha', 'good', 'joke', 'girl', 'are', 'situation', 'seekers'],
#  ['part', 'of', 'checking', 'iq'],
#  ['orry',
#   'my',
#   'roommate',
#   'took',
#   'forever',
#   'it',
#   'ok',
#   'if',
#   'come',
#   'by',
#   'now'],
#  ['lar',
#   'double',
#   'check',
#   'wif',
#   'da',
#   'hair',
#   'dresser',
#   'already',
#   'he',
#   'said',
#   'wun',
#   'cut',
#   'short',
#   'he',
#   'said',
#   'will',
#   'cut',
#   'until',
#   'look',
#   'nice'],
#  ['valued',
#   'customer',
#   'am',
#   'pleased',
#   'to',
#   'advise',
#   'you',
#   'that',
#   'following',
#   'recent',
#   'review',
#   'of',
#   'your',
#   'mob',
#   'no',
#   'you',
#   'are',
#   'awarded',
#   'with',
#   'bonus',
#   'prize',
#   'call'],
#  ['oday',
#   'is',
#   'song',
#   'dedicated',
#   'day',
#   'which',
#   'song',
#   'will',
#   'dedicate',
#   'for',
#   'me',
#   'send',
#   'this',
#   'to',
#   'all',
#   'ur',
#   'valuable',
#   'frnds',
#   'but',
#   'first',
#   'rply',
#   'me'],
#  ['rgent',
#   'ur',
#   'awarded',
#   'complimentary',
#   'trip',
#   'to',
#   'eurodisinc',
#   'trav',
#   'aco',
#   'entry',
#   'or',
#   'to',
#   'claim',
#   'txt',
#   'dis',
#   'to',
#   'morefrmmob',
#   'ls',
#   'aj'],
#  ['id',
#   'you',
#   'hear',
#   'about',
#   'the',
#   'new',
#   'divorce',
#   'barbie',
#   'it',
#   'come',
#   'with',
#   'all',
#   'of',
#   'ken',
#   'stuff'],
#  ['plane', 'to', 'give', 'on', 'this', 'month', 'end'],
#  ['ah', 'lucky', 'man', 'then', 'can', 'save', 'money', 'hee'],
#  ['inished', 'class', 'where', 'are', 'you'],
#  ['babe', 'im', 'at', 'home', 'now', 'wanna', 'do', 'something', 'xx'],
#  ['where', 'are', 'you', 'how', 'did', 'you', 'performed'],
#  ['can', 'call', 'me', 'now'],
#  ['am', 'waiting', 'machan', 'call', 'me', 'once', 'you', 'free'],
#  ['hat',
#   'cool',
#   'am',
#   'gentleman',
#   'and',
#   'will',
#   'treat',
#   'you',
#   'with',
#   'dignity',
#   'and',
#   'respect'],
#  ['like', 'you', 'people', 'very', 'much', 'but', 'am', 'very', 'shy', 'pa'],
#  ['oes', 'not', 'operate', 'after', 'lt', 'gt', 'or', 'what'],
#  ['not',
#   'the',
#   'same',
#   'here',
#   'still',
#   'looking',
#   'for',
#   'job',
#   'how',
#   'much',
#   'do',
#   'ta',
#   'earn',
#   'there'],
#  ['orry', 'll', 'call', 'later'],
#  ['did', 'you', 'call', 'me', 'just', 'now', 'ah'],
#  ['am', 'on', 'the', 'way', 'to', 'home', 'hi', 'hi'],
#  ['ou', 'will', 'be', 'in', 'the', 'place', 'of', 'that', 'man'],
#  ['up', 'next', 'stop'],
#  ['call', 'you', 'later', 'don', 'have', 'network', 'if', 'urgnt', 'sm', 'me'],
#  ['or',
#   'real',
#   'when',
#   'getting',
#   'on',
#   'yo',
#   'only',
#   'need',
#   'more',
#   'ticket',
#   'and',
#   'one',
#   'more',
#   'jacket',
#   'and',
#   'done',
#   'already',
#   'used',
#   'all',
#   'my',
#   'multis'],
#  ['started',
#   'to',
#   'send',
#   'request',
#   'to',
#   'make',
#   'it',
#   'but',
#   'pain',
#   'came',
#   'back',
#   'so',
#   'back',
#   'in',
#   'bed',
#   'double',
#   'coin',
#   'at',
#   'the',
#   'factory',
#   'too',
#   'gotta',
#   'cash',
#   'in',
#   'all',
#   'my',
#   'nitros'],
#  ['really', 'not', 'up', 'to', 'it', 'still', 'tonight', 'babe'],
#  ['la', 'kano', 'il', 'download', 'come', 'wen', 'ur', 'free'],
#  ['eah',
#   'do',
#   'don',
#   'stand',
#   'to',
#   'close',
#   'tho',
#   'you',
#   'll',
#   'catch',
#   'something'],
#  ['orry',
#   'to',
#   'be',
#   'pain',
#   'is',
#   'it',
#   'ok',
#   'if',
#   'we',
#   'meet',
#   'another',
#   'night',
#   'spent',
#   'late',
#   'afternoon',
#   'in',
#   'casualty',
#   'and',
#   'that',
#   'mean',
#   'haven',
#   'done',
#   'any',
#   'of',
#   'stuff',
#   'moro',
#   'and',
#   'that',
#   'includes',
#   'all',
#   'my',
#   'time',
#   'sheet',
#   'and',
#   'that',
#   'sorry'],
#  ['mile',
#   'in',
#   'pleasure',
#   'smile',
#   'in',
#   'pain',
#   'smile',
#   'when',
#   'trouble',
#   'pours',
#   'like',
#   'rain',
#   'smile',
#   'when',
#   'sum',
#   'hurt',
#   'smile',
#   'becoz',
#   'someone',
#   'still',
#   'love',
#   'to',
#   'see',
#   'smiling'],
#  ['lease',
#   'call',
#   'our',
#   'customer',
#   'service',
#   'representative',
#   'on',
#   'between',
#   'am',
#   'pm',
#   'you',
#   'have',
#   'won',
#   'guaranteed',
#   'cash',
#   'or',
#   'prize'],
#  ['avent',
#   'planning',
#   'to',
#   'buy',
#   'later',
#   'check',
#   'already',
#   'lido',
#   'only',
#   'got',
#   'show',
#   'in',
#   'afternoon',
#   'finish',
#   'work',
#   'already'],
#  ['our',
#   'free',
#   'ringtone',
#   'is',
#   'waiting',
#   'to',
#   'be',
#   'collected',
#   'simply',
#   'text',
#   'the',
#   'password',
#   'mix',
#   'to',
#   'to',
#   'verify',
#   'get',
#   'usher',
#   'and',
#   'britney',
#   'fml',
#   'po',
#   'box',
#   'mk',
#   'ppw'],
#  ['atching', 'telugu', 'movie', 'wat', 'abt'],
#  ['see',
#   'when',
#   'we',
#   'finish',
#   'we',
#   'have',
#   'load',
#   'of',
#   'loan',
#   'to',
#   'pay'],
#  ['wk',
#   'been',
#   'ok',
#   'on',
#   'hols',
#   'now',
#   'yes',
#   'on',
#   'for',
#   'bit',
#   'of',
#   'run',
#   'forgot',
#   'that',
#   'have',
#   'hairdresser',
#   'appointment',
#   'at',
#   'four',
#   'so',
#   'need',
#   'to',
#   'get',
#   'home',
#   'shower',
#   'beforehand',
#   'doe',
#   'that',
#   'cause',
#   'prob',
#   'for'],
#  ['see', 'cup', 'of', 'coffee', 'animation'],
#  ['lease',
#   'don',
#   'text',
#   'me',
#   'anymore',
#   'have',
#   'nothing',
#   'else',
#   'to',
#   'say'],
#  ['kay',
#   'name',
#   'ur',
#   'price',
#   'long',
#   'it',
#   'legal',
#   'wen',
#   'can',
#   'pick',
#   'them',
#   'up',
#   'ave',
#   'am',
#   'xx'],
#  ['still',
#   'looking',
#   'for',
#   'car',
#   'to',
#   'buy',
#   'and',
#   'have',
#   'not',
#   'gone',
#   'the',
#   'driving',
#   'test',
#   'yet'],
#  ['per',
#   'your',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'ha',
#   'been',
#   'set',
#   'your',
#   'callertune',
#   'for',
#   'all',
#   'callers',
#   'press',
#   'to',
#   'copy',
#   'your',
#   'friend',
#   'callertune'],
#  ['ow',
#   'you',
#   're',
#   'right',
#   'didn',
#   'mean',
#   'to',
#   'do',
#   'that',
#   'guess',
#   'once',
#   'gave',
#   'up',
#   'on',
#   'boston',
#   'men',
#   'and',
#   'changed',
#   'my',
#   'search',
#   'location',
#   'to',
#   'nyc',
#   'something',
#   'changed',
#   'cuz',
#   'on',
#   'my',
#   'signin',
#   'page',
#   'it',
#   'still',
#   'say',
#   'boston'],
#  ['mma', 'my', 'life', 'and', 'vava', 'umma', 'love', 'you', 'lot', 'dear'],
#  ['hank',
#   'lot',
#   'for',
#   'your',
#   'wish',
#   'on',
#   'my',
#   'birthday',
#   'thanks',
#   'you',
#   'for',
#   'making',
#   'my',
#   'birthday',
#   'truly',
#   'memorable'],
#  ['ight', 'll', 'hit', 'you', 'up', 'when', 'get', 'some', 'cash'],
#  ['ow',
#   'would',
#   'my',
#   'ip',
#   'address',
#   'test',
#   'that',
#   'considering',
#   'my',
#   'computer',
#   'isn',
#   'minecraft',
#   'server'],
#  ['know',
#   'grumpy',
#   'old',
#   'people',
#   'my',
#   'mom',
#   'wa',
#   'like',
#   'you',
#   'better',
#   'not',
#   'be',
#   'lying',
#   'then',
#   'again',
#   'am',
#   'always',
#   'the',
#   'one',
#   'to',
#   'play',
#   'jokes'],
#  ['ont', 'worry', 'guess', 'he', 'busy'],
#  ['hat', 'is', 'the', 'plural', 'of', 'the', 'noun', 'research'],
#  ['oing', 'for', 'dinner', 'msg', 'you', 'after'],
#  ['ok',
#   'wif',
#   'it',
#   'co',
#   'like',
#   'try',
#   'new',
#   'things',
#   'but',
#   'scared',
#   'dun',
#   'like',
#   'mah',
#   'co',
#   'said',
#   'not',
#   'too',
#   'loud'],
#  ['ent',
#   'we',
#   'are',
#   'trying',
#   'to',
#   'contact',
#   'you',
#   'last',
#   'weekend',
#   'draw',
#   'show',
#   'that',
#   'you',
#   'won',
#   'prize',
#   'guaranteed',
#   'call',
#   'claim',
#   'code',
#   'valid',
#   'hrs',
#   'only',
#   'ppm'],
#  ['ur',
#   'openin',
#   'sentence',
#   'very',
#   'formal',
#   'anyway',
#   'fine',
#   'too',
#   'juz',
#   'tt',
#   'eatin',
#   'too',
#   'much',
#   'puttin',
#   'on',
#   'weight',
#   'haha',
#   'so',
#   'anythin',
#   'special',
#   'happened'],
#  ['entered',
#   'my',
#   'cabin',
#   'my',
#   'pa',
#   'said',
#   'happy',
#   'day',
#   'bos',
#   'felt',
#   'special',
#   'she',
#   'askd',
#   'me',
#   'lunch',
#   'after',
#   'lunch',
#   'she',
#   'invited',
#   'me',
#   'to',
#   'her',
#   'apartment',
#   'we',
#   'went',
#   'there'],
#  ['ou',
#   'are',
#   'winner',
#   'have',
#   'been',
#   'specially',
#   'selected',
#   'receive',
#   'or',
#   'holiday',
#   'flights',
#   'inc',
#   'speak',
#   'to',
#   'live',
#   'operator',
#   'claim',
#   'min'],
#  ['oodo',
#   'yes',
#   'we',
#   'must',
#   'speak',
#   'friday',
#   'egg',
#   'potato',
#   'ratio',
#   'for',
#   'tortilla',
#   'needed'],
#  ['mm',
#   'my',
#   'uncle',
#   'just',
#   'informed',
#   'me',
#   'that',
#   'he',
#   'paying',
#   'the',
#   'school',
#   'directly',
#   'so',
#   'pls',
#   'buy',
#   'food'],
#  ['rivate',
#   'your',
#   'account',
#   'statement',
#   'for',
#   'show',
#   'unredeemed',
#   'bonus',
#   'points',
#   'to',
#   'claim',
#   'call',
#   'identifier',
#   'code',
#   'expires'],
#  ['rgent',
#   'your',
#   'mobile',
#   'no',
#   'wa',
#   'awarded',
#   'bonus',
#   'caller',
#   'prize',
#   'on',
#   'this',
#   'is',
#   'our',
#   'final',
#   'try',
#   'to',
#   'contact',
#   'call',
#   'from',
#   'landline',
#   'box',
#   'wr',
#   'ppm'],
#  ['ere',
#   'is',
#   'my',
#   'new',
#   'address',
#   'apples',
#   'pairs',
#   'all',
#   'that',
#   'malarky'],
#  ['odays',
#   'voda',
#   'number',
#   'ending',
#   'are',
#   'selected',
#   'to',
#   'receive',
#   'award',
#   'if',
#   'you',
#   'have',
#   'match',
#   'please',
#   'call',
#   'quoting',
#   'claim',
#   'code',
#   'standard',
#   'rate',
#   'app'],
#  ['am',
#   'going',
#   'to',
#   'sao',
#   'mu',
#   'today',
#   'will',
#   'be',
#   'done',
#   'only',
#   'at'],
#  ['predict', 'wat', 'time', 'll', 'finish', 'buying'],
#  ['ood', 'stuff', 'will', 'do'],
#  ['ust',
#   'so',
#   'that',
#   'you',
#   'know',
#   'yetunde',
#   'hasn',
#   'sent',
#   'money',
#   'yet',
#   'just',
#   'sent',
#   'her',
#   'text',
#   'not',
#   'to',
#   'bother',
#   'sending',
#   'so',
#   'it',
#   'over',
#   'you',
#   'dont',
#   'have',
#   'to',
#   'involve',
#   'yourself',
#   'in',
#   'anything',
#   'shouldn',
#   'have',
#   'imposed',
#   'anything',
#   'on',
#   'you',
#   'in',
#   'the',
#   'first',
#   'place',
#   'so',
#   'for',
#   'that',
#   'apologise'],
#  ['re', 'you', 'there', 'in', 'room'],
#  ['ey',
#   'girl',
#   'how',
#   'hope',
#   'well',
#   'me',
#   'an',
#   'del',
#   'bak',
#   'again',
#   'long',
#   'time',
#   'no',
#   'give',
#   'me',
#   'call',
#   'sum',
#   'time',
#   'from',
#   'lucyxx'],
#  ['how', 'much', 'doe', 'it', 'cost'],
#  ['home'],
#  ['ear', 'will', 'call', 'tmorrow', 'pls', 'accomodate'],
#  ['irst', 'answer', 'my', 'question'],
#  ['unshine',
#   'quiz',
#   'wkly',
#   'win',
#   'top',
#   'sony',
#   'dvd',
#   'player',
#   'if',
#   'know',
#   'which',
#   'country',
#   'the',
#   'algarve',
#   'is',
#   'in',
#   'txt',
#   'ansr',
#   'to',
#   'sp',
#   'tyrone'],
#  ['ant',
#   'get',
#   'laid',
#   'tonight',
#   'want',
#   'real',
#   'dogging',
#   'location',
#   'sent',
#   'direct',
#   'ur',
#   'mob',
#   'join',
#   'the',
#   'uk',
#   'largest',
#   'dogging',
#   'network',
#   'bt',
#   'txting',
#   'gravel',
#   'to',
#   'nt',
#   'ec',
#   'msg'],
#  ['only', 'haf', 'msn', 'it', 'yijue', 'hotmail', 'com'],
#  ['is', 'there', 'you', 'call', 'and', 'meet', 'him'],
#  ['no', 'will', 'check', 'all', 'room', 'befor', 'activity'],
#  ['ou',
#   'll',
#   'not',
#   'rcv',
#   'any',
#   'more',
#   'msg',
#   'from',
#   'the',
#   'chat',
#   'svc',
#   'for',
#   'free',
#   'hardcore',
#   'service',
#   'text',
#   'go',
#   'to',
#   'if',
#   'get',
#   'nothing',
#   'must',
#   'age',
#   'verify',
#   'with',
#   'yr',
#   'network',
#   'try',
#   'again'],
#  ['ot',
#   'lazy',
#   'to',
#   'type',
#   'forgot',
#   'in',
#   'lect',
#   'saw',
#   'pouch',
#   'but',
#   'like',
#   'not',
#   'nice'],
#  ['text', 'me', 'when', 'you', 're', 'on', 'the', 'way'],
#  ['ir', 'waiting', 'for', 'your', 'mail'],
#  ['swt',
#   'thought',
#   'nver',
#   'get',
#   'tired',
#   'of',
#   'doing',
#   'little',
#   'thing',
#   'lovable',
#   'persons',
#   'coz',
#   'somtimes',
#   'those',
#   'little',
#   'thing',
#   'occupy',
#   'biggest',
#   'part',
#   'in',
#   'their',
#   'hearts',
#   'gud',
#   'ni'],
#  ['know', 'you', 'are', 'can', 'you', 'pls', 'open', 'the', 'back'],
#  ['see', 'ya', 'not', 'on', 'the', 'dot'],
#  ['hat', 'the', 'staff', 'name', 'who', 'is', 'taking', 'class', 'for', 'us'],
#  ['reemsg',
#   'why',
#   'haven',
#   'you',
#   'replied',
#   'to',
#   'my',
#   'text',
#   'randy',
#   'sexy',
#   'female',
#   'and',
#   'live',
#   'local',
#   'luv',
#   'to',
#   'hear',
#   'from',
#   'netcollex',
#   'ltd',
#   'per',
#   'msg',
#   'reply',
#   'stop',
#   'to',
#   'end'],
#  ['mmma',
#   'will',
#   'call',
#   'after',
#   'check',
#   'in',
#   'our',
#   'life',
#   'will',
#   'begin',
#   'from',
#   'qatar',
#   'so',
#   'pls',
#   'pray',
#   'very',
#   'hard'],
#  ['deleted', 'my', 'contact', 'that', 'why'],
#  ['indu', 'got', 'job', 'in', 'birla', 'soft'],
#  ['he', 'wine', 'is', 'flowing', 'and', 'have', 'nevering'],
#  ['up',
#   'thk',
#   'cine',
#   'is',
#   'better',
#   'co',
#   'no',
#   'need',
#   'go',
#   'down',
#   'plaza',
#   'mah'],
#  ['ur', 'typical', 'reply'],
#  ['per',
#   'your',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'ha',
#   'been',
#   'set',
#   'your',
#   'callertune',
#   'for',
#   'all',
#   'callers',
#   'press',
#   'to',
#   'copy',
#   'your',
#   'friend',
#   'callertune'],
#  ['ou',
#   'are',
#   'everywhere',
#   'dirt',
#   'on',
#   'the',
#   'floor',
#   'the',
#   'windows',
#   'even',
#   'on',
#   'my',
#   'shirt',
#   'and',
#   'sometimes',
#   'when',
#   'open',
#   'my',
#   'mouth',
#   'you',
#   'are',
#   'all',
#   'that',
#   'come',
#   'flowing',
#   'out',
#   'dream',
#   'of',
#   'my',
#   'world',
#   'without',
#   'you',
#   'then',
#   'half',
#   'my',
#   'chore',
#   'are',
#   'out',
#   'too',
#   'time',
#   'of',
#   'joy',
#   'for',
#   'me',
#   'lot',
#   'of',
#   'tv',
#   'show',
#   'll',
#   'see',
#   'but',
#   'guess',
#   'like',
#   'all',
#   'thing',
#   'you',
#   'just',
#   'must',
#   'exist',
#   'like',
#   'rain',
#   'hail',
#   'and',
#   'mist',
#   'and',
#   'when',
#   'my',
#   'time',
#   'here',
#   'is',
#   'done',
#   'you',
#   'and',
#   'become',
#   'one'],
#  ['aooooright', 'are', 'you', 'at', 'work'],
#  ['leaving', 'my', 'house', 'now'],
#  ['ello',
#   'my',
#   'love',
#   'what',
#   'are',
#   'you',
#   'doing',
#   'did',
#   'you',
#   'get',
#   'to',
#   'that',
#   'interview',
#   'today',
#   'are',
#   'you',
#   'you',
#   'happy',
#   'are',
#   'you',
#   'being',
#   'good',
#   'boy',
#   'do',
#   'you',
#   'think',
#   'of',
#   'me',
#   'are',
#   'you',
#   'missing',
#   'me'],
#  ['ustomer',
#   'service',
#   'annoncement',
#   'you',
#   'have',
#   'new',
#   'year',
#   'delivery',
#   'waiting',
#   'for',
#   'you',
#   'please',
#   'call',
#   'now',
#   'to',
#   'arrange',
#   'delivery'],
#  ['ou',
#   'are',
#   'winner',
#   'have',
#   'been',
#   'specially',
#   'selected',
#   'receive',
#   'cash',
#   'or',
#   'holiday',
#   'flights',
#   'inc',
#   'speak',
#   'to',
#   'live',
#   'operator',
#   'claim'],
#  ['eep',
#   'yourself',
#   'safe',
#   'for',
#   'me',
#   'because',
#   'need',
#   'you',
#   'and',
#   'miss',
#   'you',
#   'already',
#   'and',
#   'envy',
#   'everyone',
#   'that',
#   'see',
#   'you',
#   'in',
#   'real',
#   'life'],
#  ['ew',
#   'car',
#   'and',
#   'house',
#   'for',
#   'my',
#   'parents',
#   'have',
#   'only',
#   'new',
#   'job',
#   'in',
#   'hand'],
#  ['so',
#   'in',
#   'love',
#   'with',
#   'you',
#   'excited',
#   'each',
#   'day',
#   'spend',
#   'with',
#   'you',
#   'you',
#   'make',
#   'me',
#   'so',
#   'happy'],
#  ['pls',
#   'stop',
#   'bootydelious',
#   'is',
#   'inviting',
#   'you',
#   'to',
#   'be',
#   'her',
#   'friend',
#   'reply',
#   'yes',
#   'or',
#   'no',
#   'see',
#   'her',
#   'www',
#   'sms',
#   'ac',
#   'bootydelious',
#   'stop',
#   'send',
#   'stop',
#   'frnd',
#   'to'],
#  ['angbabes',
#   'ur',
#   'order',
#   'is',
#   'on',
#   'the',
#   'way',
#   'should',
#   'receive',
#   'service',
#   'msg',
#   'download',
#   'ur',
#   'content',
#   'if',
#   'do',
#   'not',
#   'goto',
#   'wap',
#   'bangb',
#   'tv',
#   'on',
#   'ur',
#   'mobile',
#   'internet',
#   'service',
#   'menu'],
#  ['place', 'all', 'ur', 'point', 'on', 'culture', 'module', 'already'],
#  ['rgent',
#   'we',
#   'are',
#   'trying',
#   'to',
#   'contact',
#   'you',
#   'last',
#   'weekend',
#   'draw',
#   'show',
#   'that',
#   'you',
#   'have',
#   'won',
#   'prize',
#   'guaranteed',
#   'call',
#   'claim',
#   'code',
#   'valid',
#   'hrs',
#   'only'],
#  ['frnd',
#   'which',
#   'is',
#   'best',
#   'way',
#   'to',
#   'avoid',
#   'missunderstding',
#   'wit',
#   'our',
#   'beloved',
#   'one'],
#  ['reat',
#   'escape',
#   'fancy',
#   'the',
#   'bridge',
#   'but',
#   'need',
#   'her',
#   'lager',
#   'see',
#   'you',
#   'tomo'],
#  ['it',
#   'completely',
#   'in',
#   'out',
#   'of',
#   'form',
#   'clark',
#   'also',
#   'utter',
#   'waste'],
#  ['ir', 'need', 'axis', 'bank', 'account', 'no', 'and', 'bank', 'address'],
#  ['mmm',
#   'thk',
#   'sure',
#   'got',
#   'time',
#   'to',
#   'hop',
#   'ard',
#   'ya',
#   'can',
#   'go',
#   'free',
#   'abt',
#   'muz',
#   'call',
#   'to',
#   'discus',
#   'liao'],
#  ['hat', 'time', 'you', 'coming', 'down', 'later'],
#  ['loody',
#   'hell',
#   'cant',
#   'believe',
#   'you',
#   'forgot',
#   'my',
#   'surname',
#   'mr',
#   'ill',
#   'give',
#   'clue',
#   'it',
#   'spanish',
#   'and',
#   'begin',
#   'with'],
#  ['ell',
#   'gonna',
#   'finish',
#   'my',
#   'bath',
#   'now',
#   'have',
#   'good',
#   'fine',
#   'night'],
#  ['et',
#   'me',
#   'know',
#   'when',
#   'you',
#   've',
#   'got',
#   'the',
#   'money',
#   'so',
#   'carlos',
#   'can',
#   'make',
#   'the',
#   'call'],
#  ['still', 'going', 'to', 'the', 'mall'],
#  ['urn',
#   'out',
#   'my',
#   'friend',
#   'are',
#   'staying',
#   'for',
#   'the',
#   'whole',
#   'show',
#   'and',
#   'won',
#   'be',
#   'back',
#   'til',
#   'lt',
#   'gt',
#   'so',
#   'feel',
#   'free',
#   'to',
#   'go',
#   'ahead',
#   'and',
#   'smoke',
#   'that',
#   'lt',
#   'gt',
#   'worth'],
#  ['ext',
#   'her',
#   'if',
#   'she',
#   'doesnt',
#   'reply',
#   'let',
#   'me',
#   'know',
#   'so',
#   'can',
#   'have',
#   'her',
#   'log',
#   'in'],
#  ['you',
#   'just',
#   'spoke',
#   'to',
#   'maneesha',
#   'we',
#   'like',
#   'to',
#   'know',
#   'if',
#   'you',
#   'were',
#   'satisfied',
#   'with',
#   'the',
#   'experience',
#   'reply',
#   'toll',
#   'free',
#   'with',
#   'yes',
#   'or',
#   'no'],
#  ['ou',
#   'lifted',
#   'my',
#   'hope',
#   'with',
#   'the',
#   'offer',
#   'of',
#   'money',
#   'am',
#   'in',
#   'need',
#   'especially',
#   'when',
#   'the',
#   'end',
#   'of',
#   'the',
#   'month',
#   'approach',
#   'and',
#   'it',
#   'hurt',
#   'my',
#   'studying',
#   'anyways',
#   'have',
#   'gr',
#   'weekend'],
#  ['ol', 'no', 'can', 'trust', 'me'],
#  ['am',
#   'gentleman',
#   'and',
#   'will',
#   'treat',
#   'you',
#   'with',
#   'dignity',
#   'and',
#   'respect'],
#  ['will', 'you', 'guy', 'close'],
#  ['oing', 'on', 'nothing', 'great', 'bye'],
#  ['ello',
#   'handsome',
#   'are',
#   'you',
#   'finding',
#   'that',
#   'job',
#   'not',
#   'being',
#   'lazy',
#   'working',
#   'towards',
#   'getting',
#   'back',
#   'that',
#   'net',
#   'for',
#   'mummy',
#   'where',
#   'my',
#   'boytoy',
#   'now',
#   'doe',
#   'he',
#   'miss',
#   'me'],
#  ['aha', 'awesome', 'be', 'there', 'in', 'minute'],
#  ['lease',
#   'call',
#   'our',
#   'customer',
#   'service',
#   'representative',
#   'on',
#   'freephone',
#   'between',
#   'am',
#   'pm',
#   'you',
#   'have',
#   'won',
#   'guaranteed',
#   'cash',
#   'or',
#   'prize'],
#  ['ave',
#   'you',
#   'got',
#   'xmas',
#   'radio',
#   'times',
#   'if',
#   'not',
#   'will',
#   'get',
#   'it',
#   'now'],
#  ['jus',
#   'reached',
#   'home',
#   'go',
#   'bathe',
#   'first',
#   'but',
#   'my',
#   'si',
#   'using',
#   'net',
#   'tell',
#   'when',
#   'she',
#   'finish'],
#  ['re',
#   'you',
#   'unique',
#   'enough',
#   'find',
#   'out',
#   'from',
#   'th',
#   'august',
#   'www',
#   'areyouunique',
#   'co',
#   'uk'],
#  ['sorry',
#   've',
#   'joined',
#   'the',
#   'league',
#   'of',
#   'people',
#   'that',
#   'dont',
#   'keep',
#   'in',
#   'touch',
#   'you',
#   'mean',
#   'great',
#   'deal',
#   'to',
#   'me',
#   'you',
#   'have',
#   'been',
#   'friend',
#   'at',
#   'all',
#   'time',
#   'even',
#   'at',
#   'great',
#   'personal',
#   'cost',
#   'do',
#   'have',
#   'great',
#   'week'],
#  ['finally', 'completed', 'the', 'course'],
#  ['will',
#   'stop',
#   'on',
#   'itself',
#   'however',
#   'suggest',
#   'she',
#   'stay',
#   'with',
#   'someone',
#   'that',
#   'will',
#   'be',
#   'able',
#   'to',
#   'give',
#   'or',
#   'for',
#   'every',
#   'stool'],
#  ['ow',
#   'are',
#   'you',
#   'doing',
#   'hope',
#   'you',
#   've',
#   'settled',
#   'in',
#   'for',
#   'the',
#   'new',
#   'school',
#   'year',
#   'just',
#   'wishin',
#   'you',
#   'gr',
#   'day'],
#  ['ud', 'mrng', 'dear', 'hav', 'nice', 'day'],
#  ['id', 'got', 'that', 'person', 'story'],
#  ['your',
#   'hamster',
#   'dead',
#   'hey',
#   'so',
#   'tmr',
#   'meet',
#   'you',
#   'at',
#   'pm',
#   'orchard',
#   'mrt'],
#  ['it',
#   'kate',
#   'how',
#   'is',
#   'your',
#   'evening',
#   'hope',
#   'can',
#   'see',
#   'you',
#   'tomorrow',
#   'for',
#   'bit',
#   'but',
#   'have',
#   'to',
#   'bloody',
#   'babyjontet',
#   'txt',
#   'back',
#   'if',
#   'can',
#   'xxx'],
#  ['ound', 'it', 'enc', 'lt', 'gt', 'where', 'you', 'at'],
#  ['sent', 'you', 'lt', 'gt', 'buck'],
#  ['ello',
#   'darlin',
#   'ive',
#   'finished',
#   'college',
#   'now',
#   'so',
#   'txt',
#   'me',
#   'when',
#   'finish',
#   'if',
#   'can',
#   'love',
#   'kate',
#   'xxx'],
#  ['our',
#   'account',
#   'ha',
#   'been',
#   'refilled',
#   'successfully',
#   'by',
#   'inr',
#   'lt',
#   'decimal',
#   'gt',
#   'your',
#   'keralacircle',
#   'prepaid',
#   'account',
#   'balance',
#   'is',
#   'lt',
#   'decimal',
#   'gt',
#   'your',
#   'transaction',
#   'id',
#   'is',
#   'kr',
#   'lt',
#   'gt'],
#  ['oodmorning', 'sleeping', 'ga'],
#  ['call', 'me', 'alter', 'at', 'ok'],
#  ['say',
#   'until',
#   'like',
#   'dat',
#   'dun',
#   'buy',
#   'ericsson',
#   'oso',
#   'cannot',
#   'oredi',
#   'lar'],
#  ['entered',
#   'my',
#   'cabin',
#   'my',
#   'pa',
#   'said',
#   'happy',
#   'day',
#   'bos',
#   'felt',
#   'special',
#   'she',
#   'askd',
#   'me',
#   'lunch',
#   'after',
#   'lunch',
#   'she',
#   'invited',
#   'me',
#   'to',
#   'her',
#   'apartment',
#   'we',
#   'went',
#   'there'],
#  ['ight', 'yo', 'dat', 'straight', 'dogg'],
#  ['ou',
#   'please',
#   'give',
#   'connection',
#   'today',
#   'itself',
#   'before',
#   'lt',
#   'decimal',
#   'gt',
#   'or',
#   'refund',
#   'the',
#   'bill'],
#  ['oth', 'shoot', 'big', 'load', 'so', 'get', 'ready'],
#  ['hat',
#   'up',
#   'bruv',
#   'hope',
#   'you',
#   'had',
#   'great',
#   'break',
#   'do',
#   'have',
#   'rewarding',
#   'semester'],
#  ['ome', 'so', 'we', 'can', 'always', 'chat'],
#  ['good', 'study', 'well'],
#  ['up', 'how', 'noe', 'leh'],
#  ['ounds', 'great', 'are', 'you', 'home', 'now'],
#  ['inally',
#   'the',
#   'match',
#   'heading',
#   'towards',
#   'draw',
#   'your',
#   'prediction'],
#  ['ired', 'haven', 'slept', 'well', 'the', 'past', 'few', 'nights'],
#  ['asy', 'ah', 'sen', 'got', 'selected', 'mean', 'it', 'good'],
#  ['have', 'to', 'take', 'exam', 'with', 'march'],
#  ['eah',
#   'you',
#   'should',
#   'think',
#   'you',
#   'can',
#   'use',
#   'your',
#   'gt',
#   'atm',
#   'now',
#   'to',
#   'register',
#   'not',
#   'sure',
#   'but',
#   'if',
#   'there',
#   'anyway',
#   'can',
#   'help',
#   'let',
#   'me',
#   'know',
#   'but',
#   'when',
#   'you',
#   'do',
#   'be',
#   'sure',
#   'you',
#   'are',
#   'ready'],
#  ['no', 'prob', 'take', 'ur', 'time'],
#  ['here',
#   'is',
#   'called',
#   'ubandu',
#   'which',
#   'will',
#   'run',
#   'without',
#   'installing',
#   'in',
#   'hard',
#   'disk',
#   'you',
#   'can',
#   'use',
#   'that',
#   'to',
#   'copy',
#   'the',
#   'important',
#   'file',
#   'in',
#   'system',
#   'and',
#   'give',
#   'it',
#   'to',
#   'repair',
#   'shop'],
#  ['orry', 'll', 'call', 'later'],
#  ['say',
#   'leh',
#   'of',
#   'course',
#   'nothing',
#   'happen',
#   'lar',
#   'not',
#   'say',
#   'romantic',
#   'jus',
#   'bit',
#   'only',
#   'lor',
#   'thk',
#   'nite',
#   'scenery',
#   'not',
#   'so',
#   'nice',
#   'leh'],
#  ['new',
#   'mobile',
#   'from',
#   'must',
#   'go',
#   'txt',
#   'nokia',
#   'to',
#   'no',
#   'collect',
#   'yours',
#   'today',
#   'from',
#   'only',
#   'www',
#   'tc',
#   'biz',
#   'optout',
#   'gbp',
#   'mtmsg'],
#  ['ould',
#   'really',
#   'appreciate',
#   'if',
#   'you',
#   'call',
#   'me',
#   'just',
#   'need',
#   'someone',
#   'to',
#   'talk',
#   'to'],
#  ['ill',
#   'meet',
#   'ur',
#   'dream',
#   'partner',
#   'soon',
#   'is',
#   'ur',
#   'career',
#   'off',
#   'flyng',
#   'start',
#   'find',
#   'out',
#   'free',
#   'txt',
#   'horo',
#   'followed',
#   'by',
#   'ur',
#   'star',
#   'sign',
#   'horo',
#   'aries'],
#  ['ey', 'company', 'elama', 'po', 'mudyadhu'],
#  ['ife',
#   'is',
#   'more',
#   'strict',
#   'than',
#   'teacher',
#   'bcoz',
#   'teacher',
#   'teach',
#   'lesson',
#   'amp',
#   'then',
#   'conduct',
#   'exam',
#   'but',
#   'life',
#   'first',
#   'conduct',
#   'exam',
#   'amp',
#   'then',
#   'teach',
#   'lessons',
#   'happy',
#   'morning'],
#  ['ear', 'good', 'morning', 'now', 'only', 'am', 'up'],
#  ['et',
#   'down',
#   'in',
#   'gandhipuram',
#   'and',
#   'walk',
#   'to',
#   'cross',
#   'cut',
#   'road',
#   'right',
#   'side',
#   'lt',
#   'gt',
#   'street',
#   'road',
#   'and',
#   'turn',
#   'at',
#   'first',
#   'right'],
#  ['ear', 'we', 'are', 'going', 'to', 'our', 'rubber', 'place'],
#  ['orry', 'battery', 'died', 'yeah', 'here'],
#  ['es', 'here', 'tv', 'is', 'always', 'available', 'in', 'work', 'place'],
#  ['ext',
#   'meet',
#   'someone',
#   'sexy',
#   'today',
#   'can',
#   'find',
#   'date',
#   'or',
#   'even',
#   'flirt',
#   'it',
#   'up',
#   'to',
#   'join',
#   'just',
#   'reply',
#   'with',
#   'name',
#   'age',
#   'eg',
#   'sam',
#   'msg',
#   'recd',
#   'thirtyeight',
#   'penny'],
#  ['have', 'printed', 'it', 'oh', 'so', 'lt', 'gt', 'come', 'upstairs'],
#  ['ill',
#   'be',
#   'little',
#   'closer',
#   'like',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'on',
#   'the',
#   'same',
#   'street'],
#  ['here', 'are', 'you', 'when', 'wil', 'you', 'reach', 'here'],
#  ['ew',
#   'theory',
#   'argument',
#   'win',
#   'situation',
#   'but',
#   'loses',
#   'the',
#   'person',
#   'so',
#   'dont',
#   'argue',
#   'with',
#   'ur',
#   'friend',
#   'just',
#   'kick',
#   'them',
#   'amp',
#   'say',
#   'always',
#   'correct'],
#  ['have',
#   'secret',
#   'admirer',
#   'who',
#   'is',
#   'looking',
#   'make',
#   'contact',
#   'with',
#   'find',
#   'out',
#   'who',
#   'they',
#   'reveal',
#   'who',
#   'think',
#   'ur',
#   'so',
#   'special',
#   'call',
#   'on'],
#  ['omarrow', 'final', 'hearing', 'on', 'my', 'laptop', 'case', 'so', 'cant'],
#  ['tel', 'me', 'avent', 'done', 'sportsx'],
#  ['kay',
#   'no',
#   'no',
#   'just',
#   'shining',
#   'on',
#   'that',
#   'wa',
#   'meant',
#   'to',
#   'be',
#   'signing',
#   'but',
#   'that',
#   'sound',
#   'better'],
#  ['lthough',
#   'told',
#   'dat',
#   'into',
#   'baig',
#   'face',
#   'watch',
#   'now',
#   'but',
#   'really',
#   'like',
#   'watch',
#   'gave',
#   'co',
#   'it',
#   'fr',
#   'thanx',
#   'everything',
#   'dat',
#   've',
#   'done',
#   'today',
#   'touched'],
#  ['don', 'remember', 'that', 'old', 'commercial'],
#  ['oo',
#   'late',
#   'said',
#   'have',
#   'the',
#   'website',
#   'didn',
#   'have',
#   'or',
#   'dont',
#   'have',
#   'the',
#   'slipper'],
#  ['asked', 'you', 'to', 'call', 'him', 'now', 'ok'],
#  ['allis', 'wont', 'bat', 'in', 'nd', 'innings'],
#  ['didnt',
#   'work',
#   'again',
#   'oh',
#   'ok',
#   'goodnight',
#   'then',
#   'll',
#   'fix',
#   'and',
#   'have',
#   'it',
#   'ready',
#   'by',
#   'the',
#   'time',
#   'you',
#   'wake',
#   'up',
#   'you',
#   'are',
#   'very',
#   'dearly',
#   'missed',
#   'have',
#   'good',
#   'night',
#   'sleep'],
#  ['ongratulations',
#   'ur',
#   'awarded',
#   'of',
#   'cd',
#   'voucher',
#   'or',
#   'gift',
#   'guaranteed',
#   'free',
#   'entry',
#   'wkly',
#   'draw',
#   'txt',
#   'music',
#   'to',
#   'tncs',
#   'www',
#   'ldew',
#   'com',
#   'win',
#   'ppmx',
#   'age'],
#  ['anjith', 'cal', 'drpd', 'deeraj', 'and', 'deepak', 'min', 'hold'],
#  ['en',
#   'ur',
#   'lovable',
#   'bcums',
#   'angry',
#   'wid',
#   'dnt',
#   'take',
#   'it',
#   'seriously',
#   'coz',
#   'being',
#   'angry',
#   'is',
#   'most',
#   'childish',
#   'true',
#   'way',
#   'of',
#   'showing',
#   'deep',
#   'affection',
#   'care',
#   'luv',
#   'kettoda',
#   'manda',
#   'have',
#   'nice',
#   'day',
#   'da'],
#  ['hat', 'you', 'doing', 'how', 'are', 'you'],
#  ['which',
#   'is',
#   'days',
#   'also',
#   'and',
#   'the',
#   'shipping',
#   'company',
#   'that',
#   'take',
#   'wks',
#   'the',
#   'other',
#   'way',
#   'is',
#   'usps',
#   'which',
#   'take',
#   'week',
#   'but',
#   'when',
#   'it',
#   'get',
#   'to',
#   'lag',
#   'you',
#   'may',
#   'have',
#   'to',
#   'bribe',
#   'nipost',
#   'to',
#   'get',
#   'your',
#   'stuff'],
#  ['back', 'lemme', 'know', 'when', 'you', 're', 'ready'],
#  ['on',
#   'necessarily',
#   'expect',
#   'it',
#   'to',
#   'be',
#   'done',
#   'before',
#   'you',
#   'get',
#   'back',
#   'though',
#   'because',
#   'just',
#   'now',
#   'headin',
#   'out'],
#  ['mm', 'so', 'yummy', 'babe', 'nice', 'jolt', 'to', 'the', 'suzy'],
#  ['here', 'are', 'you', 'lover', 'need', 'you'],
#  ['tried',
#   'to',
#   'contact',
#   'you',
#   're',
#   'your',
#   'reply',
#   'to',
#   'our',
#   'offer',
#   'of',
#   'video',
#   'handset',
#   'anytime',
#   'network',
#   'mins',
#   'unlimited',
#   'text',
#   'camcorder',
#   'reply',
#   'or',
#   'call',
#   'now'],
#  ['parked',
#   'next',
#   'to',
#   'mini',
#   'when',
#   'are',
#   'you',
#   'coming',
#   'in',
#   'today',
#   'do',
#   'you',
#   'think'],
#  ['up'],
#  ['nyway',
#   'going',
#   'shopping',
#   'on',
#   'my',
#   'own',
#   'now',
#   'co',
#   'my',
#   'si',
#   'not',
#   'done',
#   'yet',
#   'dun',
#   'disturb',
#   'liao'],
#  ['no', 'in', 'luton', 'ring', 'me', 'if', 'ur', 'around'],
#  ['ey',
#   'am',
#   'really',
#   'horny',
#   'want',
#   'to',
#   'chat',
#   'or',
#   'see',
#   'me',
#   'naked',
#   'text',
#   'hot',
#   'to',
#   'text',
#   'charged',
#   'at',
#   'pm',
#   'to',
#   'unsubscribe',
#   'text',
#   'stop'],
#  ['hy', 'you', 'dint', 'come', 'with', 'us'],
#  ['ame', 'wana', 'plan', 'trip', 'sometme', 'then'],
#  ['ot', 'sure', 'yet', 'still', 'trying', 'to', 'get', 'hold', 'of', 'him'],
#  ['ringtone',
#   'service',
#   'ha',
#   'changed',
#   'free',
#   'credits',
#   'go',
#   'to',
#   'club',
#   'mobiles',
#   'com',
#   'to',
#   'choose',
#   'content',
#   'now',
#   'stop',
#   'txt',
#   'club',
#   'stop',
#   'to',
#   'wk',
#   'club',
#   'po',
#   'box',
#   'mk',
#   'wt'],
#  ['he', 'evo', 'just', 'had', 'to', 'download', 'flash', 'jealous'],
#  ['ingtone',
#   'club',
#   'get',
#   'the',
#   'uk',
#   'single',
#   'chart',
#   'on',
#   'your',
#   'mobile',
#   'each',
#   'week',
#   'and',
#   'choose',
#   'any',
#   'top',
#   'quality',
#   'ringtone',
#   'this',
#   'message',
#   'is',
#   'free',
#   'of',
#   'charge'],
#  ['ome',
#   'to',
#   'mu',
#   'we',
#   're',
#   'sorting',
#   'out',
#   'our',
#   'narcotic',
#   'situation'],
#  ['ight',
#   'ha',
#   'ended',
#   'for',
#   'another',
#   'day',
#   'morning',
#   'ha',
#   'come',
#   'in',
#   'special',
#   'way',
#   'may',
#   'you',
#   'smile',
#   'like',
#   'the',
#   'sunny',
#   'ray',
#   'and',
#   'leaf',
#   'your',
#   'worry',
#   'at',
#   'the',
#   'blue',
#   'blue',
#   'bay'],
#  ['mv',
#   'bonus',
#   'special',
#   'pound',
#   'of',
#   'genuine',
#   'hmv',
#   'voucher',
#   'to',
#   'be',
#   'won',
#   'just',
#   'answer',
#   'easy',
#   'questions',
#   'play',
#   'now',
#   'send',
#   'hmv',
#   'to',
#   'more',
#   'info',
#   'www',
#   'percent',
#   'real',
#   'com'],
#  ['sf', 'guess', 'might', 'well', 'take', 'car'],
#  ['objection', 'my', 'bf', 'not', 'coming'],
#  ['hanx'],
#  ['ell', 'rob', 'to', 'mack', 'his', 'gf', 'in', 'the', 'theater'],
#  ['wesome', 'll', 'see', 'you', 'in', 'bit'],
#  ['ust',
#   'sent',
#   'it',
#   'so',
#   'what',
#   'type',
#   'of',
#   'food',
#   'do',
#   'you',
#   'like'],
#  ['ll',
#   'done',
#   'all',
#   'handed',
#   'in',
#   'celebration',
#   'in',
#   'full',
#   'swing',
#   'yet'],
#  ['ou', 'got', 'called', 'tool'],
#  ['en',
#   'miss',
#   'someone',
#   'the',
#   'person',
#   'is',
#   'definitely',
#   'special',
#   'for',
#   'but',
#   'if',
#   'the',
#   'person',
#   'is',
#   'so',
#   'special',
#   'why',
#   'to',
#   'miss',
#   'them',
#   'just',
#   'keep',
#   'in',
#   'touch',
#   'gdeve'],
#  ['asked', 'for', 'money', 'how', 'far'],
#  ['kie'],
#  ['eah',
#   'think',
#   'my',
#   'usual',
#   'guy',
#   'still',
#   'passed',
#   'out',
#   'from',
#   'last',
#   'night',
#   'if',
#   'you',
#   'get',
#   'ahold',
#   'of',
#   'anybody',
#   'let',
#   'me',
#   'know',
#   'and',
#   'll',
#   'throw',
#   'down'],
#  ['might',
#   'come',
#   'by',
#   'tonight',
#   'then',
#   'if',
#   'my',
#   'class',
#   'let',
#   'out',
#   'early'],
#  [],
#  ['baby',
#   'im',
#   'cruisin',
#   'with',
#   'my',
#   'girl',
#   'friend',
#   'what',
#   'up',
#   'give',
#   'me',
#   'call',
#   'in',
#   'and',
#   'hour',
#   'at',
#   'home',
#   'if',
#   'thats',
#   'alright',
#   'or',
#   'fone',
#   'me',
#   'on',
#   'this',
#   'fone',
#   'now',
#   'love',
#   'jenny',
#   'xxx'],
#  ['life',
#   'mean',
#   'lot',
#   'to',
#   'me',
#   'not',
#   'because',
#   'love',
#   'my',
#   'life',
#   'but',
#   'because',
#   'love',
#   'the',
#   'people',
#   'in',
#   'my',
#   'life',
#   'the',
#   'world',
#   'call',
#   'them',
#   'friends',
#   'call',
#   'them',
#   'my',
#   'world',
#   'ge'],
#  ['ear',
#   'shall',
#   'mail',
#   'tonite',
#   'busy',
#   'in',
#   'the',
#   'street',
#   'shall',
#   'update',
#   'you',
#   'tonite',
#   'things',
#   'are',
#   'looking',
#   'ok',
#   'varunnathu',
#   'edukkukayee',
#   'raksha',
#   'ollu',
#   'but',
#   'good',
#   'one',
#   'in',
#   'real',
#   'sense'],
#  ['ey', 'you', 'told', 'your', 'name', 'to', 'gautham', 'ah'],
#  ['af', 'found', 'him', 'feel', 'so', 'stupid', 'da', 'cam', 'wa', 'working'],
#  ['ops', 'got', 'that', 'bit'],
#  ['re', 'you', 'this', 'much', 'buzy'],
#  ['accidentally', 'deleted', 'the', 'message', 'resend', 'please'],
#  ['mobile',
#   'customer',
#   'you',
#   'may',
#   'now',
#   'claim',
#   'your',
#   'free',
#   'camera',
#   'phone',
#   'upgrade',
#   'pay',
#   'go',
#   'sim',
#   'card',
#   'for',
#   'your',
#   'loyalty',
#   'call',
#   'on',
#   'offer',
#   'end',
#   'thfeb',
#   'apply'],
#  ['nless',
#   'it',
#   'situation',
#   'where',
#   'you',
#   'go',
#   'gurl',
#   'would',
#   'be',
#   'more',
#   'appropriate'],
#  ['urt',
#   'me',
#   'tease',
#   'me',
#   'make',
#   'me',
#   'cry',
#   'but',
#   'in',
#   'the',
#   'end',
#   'of',
#   'my',
#   'life',
#   'when',
#   'die',
#   'plz',
#   'keep',
#   'one',
#   'rose',
#   'on',
#   'my',
#   'grave',
#   'and',
#   'say',
#   'stupid',
#   'miss',
#   'have',
#   'nice',
#   'day',
#   'bslvyl'],
#  ['cant', 'pick', 'the', 'phone', 'right', 'now', 'pls', 'send', 'message'],
#  ['eed',
#   'coffee',
#   'run',
#   'tomo',
#   'can',
#   'believe',
#   'it',
#   'that',
#   'time',
#   'of',
#   'week',
#   'already'],
#  ['wesome',
#   'remember',
#   'the',
#   'last',
#   'time',
#   'we',
#   'got',
#   'somebody',
#   'high',
#   'for',
#   'the',
#   'first',
#   'time',
#   'with',
#   'diesel'],
#  ['hit',
#   'that',
#   'is',
#   'really',
#   'shocking',
#   'and',
#   'scary',
#   'cant',
#   'imagine',
#   'for',
#   'second',
#   'def',
#   'up',
#   'for',
#   'night',
#   'out',
#   'do',
#   'think',
#   'there',
#   'is',
#   'somewhere',
#   'could',
#   'crash',
#   'for',
#   'night',
#   'save',
#   'on',
#   'taxi'],
#  ['and',
#   'by',
#   'the',
#   'way',
#   'you',
#   'do',
#   'have',
#   'more',
#   'food',
#   'in',
#   'your',
#   'fridge',
#   'want',
#   'to',
#   'go',
#   'out',
#   'for',
#   'meal',
#   'tonight'],
#  ['is', 'womdarfull', 'actor'],
#  ['ms',
#   'ac',
#   'blind',
#   'date',
#   'rodds',
#   'is',
#   'from',
#   'aberdeen',
#   'united',
#   'kingdom',
#   'check',
#   'him',
#   'out',
#   'http',
#   'img',
#   'sms',
#   'ac',
#   'icmb',
#   'cktz',
#   'no',
#   'blind',
#   'date',
#   'send',
#   'hide'],
#  ['up', 'from', 'what', 'remb', 'think', 'should', 'be', 'can', 'book'],
#  ['ask', 'if', 'wana', 'meet', 'up'],
#  ['ol',
#   'yes',
#   'our',
#   'friendship',
#   'is',
#   'hanging',
#   'on',
#   'thread',
#   'cause',
#   'won',
#   'buy',
#   'stuff'],
#  ['hemob',
#   'check',
#   'out',
#   'our',
#   'newest',
#   'selection',
#   'of',
#   'content',
#   'games',
#   'tones',
#   'gossip',
#   'babe',
#   'and',
#   'sport',
#   'keep',
#   'your',
#   'mobile',
#   'fit',
#   'and',
#   'funky',
#   'text',
#   'wap',
#   'to'],
#  ['here',
#   'are',
#   'the',
#   'garage',
#   'keys',
#   'they',
#   'aren',
#   'on',
#   'the',
#   'bookshelf'],
#  ['oday',
#   'is',
#   'accept',
#   'day',
#   'accept',
#   'me',
#   'as',
#   'brother',
#   'sister',
#   'lover',
#   'dear',
#   'best',
#   'clos',
#   'lvblefrnd',
#   'jstfrnd',
#   'cutefrnd',
#   'lifpartnr',
#   'belovd',
#   'swtheart',
#   'bstfrnd',
#   'no',
#   'rply',
#   'mean',
#   'enemy'],
#  ['hink',
#   'ur',
#   'smart',
#   'win',
#   'this',
#   'week',
#   'in',
#   'our',
#   'weekly',
#   'quiz',
#   'text',
#   'play',
#   'to',
#   'now',
#   'cs',
#   'winnersclub',
#   'po',
#   'box',
#   'uz',
#   'gbp',
#   'week'],
#  ['say',
#   'he',
#   'll',
#   'give',
#   'me',
#   'call',
#   'when',
#   'his',
#   'friend',
#   'got',
#   'the',
#   'money',
#   'but',
#   'that',
#   'he',
#   'definitely',
#   'buying',
#   'before',
#   'the',
#   'end',
#   'of',
#   'the',
#   'week'],
#  ['the',
#   'way',
#   'wa',
#   'with',
#   'day',
#   'is',
#   'the',
#   'normal',
#   'way',
#   'this',
#   'is',
#   'the',
#   'real',
#   'me',
#   'ur',
#   'unique',
#   'hope',
#   'know',
#   'the',
#   'rest',
#   'of',
#   'mylife',
#   'hope',
#   'find',
#   'wot',
#   'wa',
#   'lost'],
#  ['ou', 'made', 'my', 'day', 'do', 'have', 'great', 'day', 'too'],
#  ['advance', 'happy', 'pongal'],
#  ['mmm',
#   'guess',
#   'we',
#   'can',
#   'go',
#   'kb',
#   'power',
#   'yoga',
#   'haha',
#   'dunno',
#   'we',
#   'can',
#   'tahan',
#   'power',
#   'yoga',
#   'anot',
#   'thk',
#   'got',
#   'lo',
#   'oso',
#   'forgot',
#   'liao'],
#  ['ot', 'really', 'dude', 'have', 'no', 'friend', 'afraid'],
#  ['ecember',
#   'only',
#   'had',
#   'your',
#   'mobile',
#   'mths',
#   'you',
#   'are',
#   'entitled',
#   'to',
#   'update',
#   'to',
#   'the',
#   'latest',
#   'colour',
#   'camera',
#   'mobile',
#   'for',
#   'free',
#   'call',
#   'the',
#   'mobile',
#   'update',
#   'co',
#   'free',
#   'on'],
#  ['offee', 'cake', 'guess'],
#  ['erry', 'christmas', 'to', 'you', 'too', 'babe', 'love', 'ya', 'kisses'],
#  ['ey',
#   'why',
#   'dont',
#   'we',
#   'just',
#   'go',
#   'watch',
#   'men',
#   'and',
#   'have',
#   'lunch',
#   'haha'],
#  ['ud',
#   'tell',
#   'ppl',
#   'im',
#   'gona',
#   'bit',
#   'co',
#   'bus',
#   'hav',
#   'gon',
#   'past',
#   'co',
#   'they',
#   'were',
#   'full',
#   'im',
#   'still',
#   'waitin',
#   'pete'],
#  ['hat',
#   'would',
#   'be',
#   'great',
#   'we',
#   'll',
#   'be',
#   'at',
#   'the',
#   'guild',
#   'could',
#   'meet',
#   'on',
#   'bristol',
#   'road',
#   'or',
#   'somewhere',
#   'will',
#   'get',
#   'in',
#   'touch',
#   'over',
#   'weekend',
#   'our',
#   'plan',
#   'take',
#   'flight',
#   'have',
#   'good',
#   'week'],
#  ['problem', 'how', 'are', 'you', 'doing'],
#  ['calls', 'messages', 'missed', 'call'],
#  ['da', 'how', 'is', 'the', 'today', 'class'],
#  ['say',
#   'that',
#   'good',
#   'sign',
#   'but',
#   'well',
#   'you',
#   'know',
#   'my',
#   'track',
#   'record',
#   'at',
#   'reading',
#   'woman'],
#  ['ool', 'text', 'me', 'when', 'you', 're', 'parked'],
#  ['reading',
#   'the',
#   'text',
#   'just',
#   'sent',
#   'you',
#   'it',
#   'meant',
#   'to',
#   'be',
#   'joke',
#   'so',
#   'read',
#   'it',
#   'in',
#   'that',
#   'light'],
#  ['apo', 'good', 'movie'],
#  ['aybe',
#   'could',
#   'get',
#   'book',
#   'out',
#   'tomo',
#   'then',
#   'return',
#   'it',
#   'immediately',
#   'or',
#   'something'],
#  ['all',
#   'germany',
#   'for',
#   'only',
#   'penny',
#   'per',
#   'minute',
#   'call',
#   'from',
#   'fixed',
#   'line',
#   'via',
#   'access',
#   'number',
#   'no',
#   'prepayment',
#   'direct',
#   'access'],
#  ['ny',
#   'chance',
#   'you',
#   'might',
#   'have',
#   'had',
#   'with',
#   'me',
#   'evaporated',
#   'soon',
#   'you',
#   'violated',
#   'my',
#   'privacy',
#   'by',
#   'stealing',
#   'my',
#   'phone',
#   'number',
#   'from',
#   'your',
#   'employer',
#   'paperwork',
#   'not',
#   'cool',
#   'at',
#   'all',
#   'please',
#   'do',
#   'not',
#   'contact',
#   'me',
#   'again',
#   'or',
#   'will',
#   'report',
#   'you',
#   'to',
#   'your',
#   'supervisor'],
#  ['alentines',
#   'day',
#   'special',
#   'win',
#   'over',
#   'in',
#   'our',
#   'quiz',
#   'and',
#   'take',
#   'your',
#   'partner',
#   'on',
#   'the',
#   'trip',
#   'of',
#   'lifetime',
#   'send',
#   'go',
#   'to',
#   'now',
#   'msg',
#   'rcvd',
#   'custcare'],
#  ['daaaaa', 'am', 'home', 'babe', 'are', 'you', 'still', 'up'],
#  ['ool',
#   'so',
#   'how',
#   'come',
#   'you',
#   'havent',
#   'been',
#   'wined',
#   'and',
#   'dined',
#   'before'],
#  ['ust', 'sleeping', 'and', 'surfing'],
#  ['orry', 'll', 'call', 'later'],
#  ['calling', 'me', 'right', 'call', 'my', 'hand', 'phone'],
#  ['that', 'great', 'thanx', 'lot'],
#  ['take',
#   'it',
#   'the',
#   'post',
#   'ha',
#   'come',
#   'then',
#   'you',
#   'must',
#   'have',
#   'of',
#   'text',
#   'now',
#   'happy',
#   'reading',
#   'my',
#   'one',
#   'from',
#   'wiv',
#   'hello',
#   'caroline',
#   'at',
#   'the',
#   'end',
#   'is',
#   'my',
#   'favourite',
#   'bless',
#   'him'],
# ...
#   'fave',
#   'position'],
#  ['ude', 'we', 'should', 'go', 'sup', 'again'],
#  ['oyyooo',
#   'know',
#   'how',
#   'to',
#   'change',
#   'permission',
#   'for',
#   'drive',
#   'in',
#   'mac',
#   'my',
#   'usb',
#   'flash',
#   'drive'],
#  ['ibbs', 'unsold', 'mike', 'hussey'],
#  ['like',
#   'to',
#   'talk',
#   'pa',
#   'but',
#   'am',
#   'not',
#   'able',
#   'to',
#   'dont',
#   'know'],
#  ['dun',
#   'cut',
#   'too',
#   'short',
#   'leh',
#   'dun',
#   'like',
#   'ah',
#   'she',
#   'failed',
#   'she',
#   'quite',
#   'sad'],
#  ['ou', 'unbelievable', 'faglord'],
#  ['ife', 'how', 'she', 'knew', 'the', 'time', 'of', 'murder', 'exactly'],
#  ['hy', 'do', 'you', 'ask', 'princess'],
#  ['am', 'great', 'princess', 'what', 'are', 'you', 'thinking', 'about', 'me'],
#  ['utter',
#   'cutter',
#   'ctter',
#   'cttergg',
#   'cttargg',
#   'ctargg',
#   'ctagg',
#   'ie',
#   'you'],
#  ['ok',
#   'noe',
#   're',
#   'busy',
#   'but',
#   'really',
#   'too',
#   'bored',
#   'so',
#   'msg',
#   'oso',
#   'dunno',
#   'wat',
#   'colour',
#   'she',
#   'choose',
#   'me',
#   'one'],
#  ['oesn',
#   'have',
#   'class',
#   'early',
#   'tomorrow',
#   'and',
#   'thus',
#   'shouldn',
#   'be',
#   'trying',
#   'to',
#   'smoke',
#   'at',
#   'lt',
#   'gt'],
#  ['uperb',
#   'thought',
#   'be',
#   'grateful',
#   'that',
#   'dont',
#   'have',
#   'everything',
#   'want',
#   'that',
#   'mean',
#   'still',
#   'have',
#   'an',
#   'opportunity',
#   'to',
#   'be',
#   'happier',
#   'tomorrow',
#   'than',
#   'are',
#   'today'],
#  ['ope', 'you', 'are', 'having', 'good', 'week', 'just', 'checking', 'in'],
#  ['used',
#   'to',
#   'it',
#   'just',
#   'hope',
#   'my',
#   'agent',
#   'don',
#   'drop',
#   'me',
#   'since',
#   've',
#   'only',
#   'booked',
#   'few',
#   'thing',
#   'this',
#   'year',
#   'this',
#   'whole',
#   'me',
#   'in',
#   'boston',
#   'them',
#   'in',
#   'nyc',
#   'wa',
#   'an',
#   'experiment'],
#  ['hursday',
#   'night',
#   'yeah',
#   'sure',
#   'thing',
#   'we',
#   'll',
#   'work',
#   'it',
#   'out',
#   'then'],
#  ['our',
#   'free',
#   'ringtone',
#   'is',
#   'waiting',
#   'to',
#   'be',
#   'collected',
#   'simply',
#   'text',
#   'the',
#   'password',
#   'mix',
#   'to',
#   'to',
#   'verify',
#   'get',
#   'usher',
#   'and',
#   'britney',
#   'fml',
#   'po',
#   'box',
#   'mk',
#   'ppw'],
#  ['robably',
#   'money',
#   'worries',
#   'thing',
#   'are',
#   'coming',
#   'due',
#   'and',
#   'have',
#   'several',
#   'outstanding',
#   'invoice',
#   'for',
#   'work',
#   'did',
#   'two',
#   'and',
#   'three',
#   'month',
#   'ago'],
#  ['ow', 'is', 'it', 'possible', 'to', 'teach', 'you', 'and', 'where'],
#  ['wonder',
#   'if',
#   'your',
#   'phone',
#   'battery',
#   'went',
#   'dead',
#   'had',
#   'to',
#   'tell',
#   'you',
#   'love',
#   'you',
#   'babe'],
#  ['ovely', 'smell', 'on', 'this', 'bus', 'and', 'it', 'ain', 'tobacco'],
#  ['re',
#   'all',
#   'getting',
#   'worried',
#   'over',
#   'here',
#   'derek',
#   'and',
#   'taylor',
#   'have',
#   'already',
#   'assumed',
#   'the',
#   'worst'],
#  ['ey', 'what', 'up', 'charles', 'sorry', 'about', 'the', 'late', 'reply'],
#  ['ll',
#   'the',
#   'lastest',
#   'from',
#   'stereophonics',
#   'marley',
#   'dizzee',
#   'racal',
#   'libertine',
#   'and',
#   'the',
#   'strokes',
#   'win',
#   'nookii',
#   'game',
#   'with',
#   'flirt',
#   'click',
#   'themob',
#   'wap',
#   'bookmark',
#   'or',
#   'text',
#   'wap',
#   'to'],
#  ['ll',
#   'give',
#   'her',
#   'once',
#   'have',
#   'it',
#   'plus',
#   'she',
#   'said',
#   'grinule',
#   'greet',
#   'you',
#   'whenever',
#   'we',
#   'speak'],
#  ['hite', 'fudge', 'oreo', 'are', 'in', 'store'],
#  ['anuary',
#   'male',
#   'sale',
#   'hot',
#   'gay',
#   'chat',
#   'now',
#   'cheaper',
#   'call',
#   'national',
#   'rate',
#   'from',
#   'min',
#   'cheap',
#   'to',
#   'min',
#   'peak',
#   'to',
#   'stop',
#   'text',
#   'call',
#   'min'],
#  ['love',
#   'how',
#   'come',
#   'it',
#   'took',
#   'you',
#   'so',
#   'long',
#   'to',
#   'leave',
#   'for',
#   'zaher',
#   'got',
#   'your',
#   'word',
#   'on',
#   'ym',
#   'and',
#   'wa',
#   'happy',
#   'to',
#   'see',
#   'them',
#   'but',
#   'wa',
#   'sad',
#   'you',
#   'had',
#   'left',
#   'miss',
#   'you'],
#  ['am', 'sorry', 'it', 'hurt', 'you'],
#  ['an',
#   'feel',
#   'nauseous',
#   'so',
#   'pissed',
#   'didn',
#   'eat',
#   'any',
#   'sweet',
#   'all',
#   'week',
#   'cause',
#   'today',
#   'wa',
#   'planning',
#   'to',
#   'pig',
#   'out',
#   'wa',
#   'dieting',
#   'all',
#   'week',
#   'and',
#   'now',
#   'not',
#   'hungry'],
#  ['lor',
#   'but',
#   'not',
#   'too',
#   'early',
#   'me',
#   'still',
#   'having',
#   'project',
#   'meeting',
#   'now'],
#  ['all', 'me', 'da', 'am', 'waiting', 'for', 'your', 'call'],
#  ['could',
#   'ask',
#   'carlos',
#   'if',
#   'we',
#   'could',
#   'get',
#   'more',
#   'if',
#   'anybody',
#   'else',
#   'can',
#   'chip',
#   'in'],
#  ['actually',
#   'about',
#   'to',
#   'send',
#   'you',
#   'reminder',
#   'today',
#   'have',
#   'wonderful',
#   'weekend'],
#  ['hen',
#   'people',
#   'see',
#   'my',
#   'msgs',
#   'they',
#   'think',
#   'iam',
#   'addicted',
#   'to',
#   'msging',
#   'they',
#   'are',
#   'wrong',
#   'bcoz',
#   'they',
#   'don',
#   'know',
#   'that',
#   'iam',
#   'addicted',
#   'to',
#   'my',
#   'sweet',
#   'friends',
#   'bslvyl'],
#  ['ey',
#   'you',
#   'gave',
#   'them',
#   'your',
#   'photo',
#   'when',
#   'you',
#   'registered',
#   'for',
#   'driving',
#   'ah',
#   'tmr',
#   'wanna',
#   'meet',
#   'at',
#   'yck'],
#  ['ont', 'talk', 'to', 'him', 'ever', 'ok', 'it', 'my', 'word'],
#  ['hen', 'wana', 'see', 'it', 'then'],
#  ['ma',
#   'way',
#   'to',
#   'school',
#   'can',
#   'you',
#   'pls',
#   'send',
#   'me',
#   'ashley',
#   'number'],
#  ['shall', 'be', 'fine', 'have', 'avalarr', 'now', 'will', 'hollalater'],
#  ['he',
#   'went',
#   'to',
#   'attend',
#   'another',
#   'two',
#   'round',
#   'today',
#   'but',
#   'still',
#   'did',
#   'reach',
#   'home'],
#  ['ctually',
#   'deleted',
#   'my',
#   'old',
#   'website',
#   'now',
#   'blogging',
#   'at',
#   'magicalsongs',
#   'blogspot',
#   'com'],
#  ['wait', 'chikku', 'il', 'send', 'aftr', 'lt', 'gt', 'min'],
#  ['ut',
#   'on',
#   'diet',
#   'and',
#   'ate',
#   'too',
#   'many',
#   'slice',
#   'of',
#   'pizza',
#   'yesterday',
#   'ugh',
#   'always',
#   'on',
#   'diet'],
#  ['will', 'give', 'my', 'kvb', 'acc', 'details'],
#  ['all', 'have', 'to', 'come', 'ah'],
#  ['oney',
#   'you',
#   'lucky',
#   'winner',
#   'claim',
#   'your',
#   'prize',
#   'text',
#   'money',
#   'over',
#   'million',
#   'to',
#   'give',
#   'away',
#   'ppt',
#   'normal',
#   'text',
#   'rate',
#   'box',
#   'jy'],
#  ['really',
#   'sorry',
#   'won',
#   'able',
#   'do',
#   'this',
#   'friday',
#   'hope',
#   'can',
#   'find',
#   'an',
#   'alternative',
#   'hope',
#   'yr',
#   'term',
#   'going',
#   'ok'],
#  ['ongratulations',
#   'ore',
#   'mo',
#   'owo',
#   're',
#   'wa',
#   'enjoy',
#   'it',
#   'and',
#   'wish',
#   'you',
#   'many',
#   'happy',
#   'moment',
#   'to',
#   'and',
#   'fro',
#   'wherever',
#   'you',
#   'go'],
#  ['do', 'you', 'have', 'samus', 'shoulder', 'yet'],
#  ['hat',
#   'time',
#   'you',
#   'think',
#   'you',
#   'll',
#   'have',
#   'it',
#   'need',
#   'to',
#   'know',
#   'when',
#   'should',
#   'be',
#   'near',
#   'campus'],
#  ['ear',
#   'matthew',
#   'please',
#   'call',
#   'from',
#   'landline',
#   'your',
#   'complimentary',
#   'lux',
#   'tenerife',
#   'holiday',
#   'or',
#   'cash',
#   'await',
#   'collection',
#   'ppm',
#   'sae',
#   'cs',
#   'box',
#   'sk',
#   'xh'],
#  ['hen', 'dun', 'wear', 'jean', 'lor'],
#  ['ince', 'when', 'which', 'side', 'any', 'fever', 'any', 'vomitin'],
#  ['are', 'you', 'in', 'college'],
#  ['rgent',
#   'call',
#   'from',
#   'landline',
#   'your',
#   'complimentary',
#   'tenerife',
#   'holiday',
#   'or',
#   'cash',
#   'await',
#   'collection',
#   'sae',
#   'cs',
#   'box',
#   'hp',
#   'yf',
#   'ppm'],
#  ['etter',
#   'made',
#   'up',
#   'for',
#   'friday',
#   'and',
#   'stuffed',
#   'myself',
#   'like',
#   'pig',
#   'yesterday',
#   'now',
#   'feel',
#   'bleh',
#   'but',
#   'at',
#   'least',
#   'it',
#   'not',
#   'writhing',
#   'pain',
#   'kind',
#   'of',
#   'bleh'],
#  ['we',
#   'sell',
#   'it',
#   'all',
#   'so',
#   'we',
#   'll',
#   'have',
#   'ton',
#   'if',
#   'coins',
#   'then',
#   'sell',
#   'our',
#   'coin',
#   'to',
#   'someone',
#   'thru',
#   'paypal',
#   'voila',
#   'money',
#   'back',
#   'in',
#   'life',
#   'pockets'],
#  ['heyre',
#   'doing',
#   'it',
#   'to',
#   'lot',
#   'of',
#   'places',
#   'only',
#   'hospital',
#   'and',
#   'medical',
#   'place',
#   'are',
#   'safe'],
#  ['ow',
#   'about',
#   'getting',
#   'in',
#   'touch',
#   'with',
#   'folk',
#   'waiting',
#   'for',
#   'company',
#   'just',
#   'txt',
#   'back',
#   'your',
#   'name',
#   'and',
#   'age',
#   'to',
#   'opt',
#   'in',
#   'enjoy',
#   'the',
#   'community',
#   'sms'],
#  ['nd',
#   'also',
#   've',
#   'sorta',
#   'blown',
#   'him',
#   'off',
#   'couple',
#   'time',
#   'recently',
#   'so',
#   'id',
#   'rather',
#   'not',
#   'text',
#   'him',
#   'out',
#   'of',
#   'the',
#   'blue',
#   'looking',
#   'for',
#   'weed'],
#  ['sent',
#   'my',
#   'score',
#   'to',
#   'sophas',
#   'and',
#   'had',
#   'to',
#   'do',
#   'secondary',
#   'application',
#   'for',
#   'few',
#   'schools',
#   'think',
#   'if',
#   'you',
#   'are',
#   'thinking',
#   'of',
#   'applying',
#   'do',
#   'research',
#   'on',
#   'cost',
#   'also',
#   'contact',
#   'joke',
#   'ogunrinde',
#   'her',
#   'school',
#   'is',
#   'one',
#   'me',
#   'the',
#   'less',
#   'expensive',
#   'one'],
#  ['cant',
#   'wait',
#   'to',
#   'see',
#   'you',
#   'how',
#   'were',
#   'the',
#   'photo',
#   'were',
#   'useful'],
#  ['cash',
#   'balance',
#   'is',
#   'currently',
#   'pound',
#   'to',
#   'maximize',
#   'ur',
#   'cash',
#   'in',
#   'now',
#   'send',
#   'go',
#   'to',
#   'only',
#   'msg',
#   'cc',
#   'po',
#   'box',
#   'tcr'],
#  ['ey',
#   'booked',
#   'the',
#   'kb',
#   'on',
#   'sat',
#   'already',
#   'what',
#   'other',
#   'lesson',
#   'are',
#   'we',
#   'going',
#   'for',
#   'ah',
#   'keep',
#   'your',
#   'sat',
#   'night',
#   'free',
#   'we',
#   'need',
#   'to',
#   'meet',
#   'and',
#   'confirm',
#   'our',
#   'lodging'],
#  ['hk', 'in', 'ur', 'belovd', 'dict'],
#  ['that', 'what', 'time', 'you', 'want', 'me', 'to', 'come'],
#  ['wesome', 'lemme', 'know', 'whenever', 'you', 're', 'around'],
#  ['hb', 'ok', 'lor', 'thanx'],
#  ['eautiful',
#   'truth',
#   'against',
#   'gravity',
#   'read',
#   'carefully',
#   'our',
#   'heart',
#   'feel',
#   'light',
#   'when',
#   'someone',
#   'is',
#   'in',
#   'it',
#   'but',
#   'it',
#   'feel',
#   'very',
#   'heavy',
#   'when',
#   'someone',
#   'leaf',
#   'it',
#   'good',
#   'night'],
#  ['lso', 'remember', 'to', 'get', 'dobby', 'bowl', 'from', 'your', 'car'],
#  ['ilthy', 'story', 'and', 'girl', 'waiting', 'for', 'your'],
#  ['orry',
#   'now',
#   'then',
#   'ur',
#   'msg',
#   'yar',
#   'lor',
#   'so',
#   'poor',
#   'thing',
#   'but',
#   'only',
#   'one',
#   'night',
#   'tmr',
#   'll',
#   'have',
#   'brand',
#   'new',
#   'room',
#   'sleep',
#   'in'],
#  ['ove',
#   'isn',
#   'decision',
#   'it',
#   'feeling',
#   'if',
#   'we',
#   'could',
#   'decide',
#   'who',
#   'to',
#   'love',
#   'then',
#   'life',
#   'would',
#   'be',
#   'much',
#   'simpler',
#   'but',
#   'then',
#   'less',
#   'magical'],
#  ['elp', 'apparently', 'he', 'retired'],
#  ['sort',
#   'code',
#   'is',
#   'and',
#   'acc',
#   'no',
#   'is',
#   'the',
#   'bank',
#   'is',
#   'natwest',
#   'can',
#   'you',
#   'reply',
#   'to',
#   'confirm',
#   've',
#   'sent',
#   'this',
#   'to',
#   'the',
#   'right',
#   'person'],
#  ['here'],
#  ['sure', 'can', 'take', 'any', 'sick', 'time'],
#  ['rgent',
#   'we',
#   'are',
#   'trying',
#   'to',
#   'contact',
#   'today',
#   'draw',
#   'show',
#   'that',
#   'you',
#   'have',
#   'won',
#   'prize',
#   'guaranteed',
#   'call',
#   'from',
#   'land',
#   'line',
#   'claim',
#   'valid',
#   'hrs',
#   'only'],
#  ['atching',
#   'cartoon',
#   'listening',
#   'music',
#   'amp',
#   'at',
#   'eve',
#   'had',
#   'to',
#   'go',
#   'temple',
#   'amp',
#   'church',
#   'what',
#   'about'],
#  ['chad',
#   'which',
#   'gymnastics',
#   'class',
#   'do',
#   'you',
#   'wanna',
#   'take',
#   'the',
#   'site',
#   'say',
#   'christian',
#   'class',
#   'is',
#   'full'],
#  ['re', 'you', 'this', 'much', 'buzy'],
#  ['better',
#   'still',
#   'can',
#   'you',
#   'catch',
#   'her',
#   'and',
#   'let',
#   'ask',
#   'her',
#   'if',
#   'she',
#   'can',
#   'sell',
#   'lt',
#   'gt',
#   'for',
#   'me'],
#  ['am',
#   'not',
#   'sure',
#   'about',
#   'night',
#   'menu',
#   'know',
#   'only',
#   'about',
#   'noon',
#   'menu'],
#  ['hat',
#   'do',
#   'want',
#   'when',
#   'come',
#   'back',
#   'beautiful',
#   'necklace',
#   'token',
#   'of',
#   'my',
#   'heart',
#   'for',
#   'you',
#   'thats',
#   'what',
#   'will',
#   'give',
#   'but',
#   'only',
#   'to',
#   'my',
#   'wife',
#   'of',
#   'my',
#   'liking',
#   'be',
#   'that',
#   'and',
#   'see',
#   'no',
#   'one',
#   'can',
#   'give',
#   'you',
#   'that',
#   'dont',
#   'call',
#   'me',
#   'will',
#   'wait',
#   'till',
#   'come'],
#  ['re', 'you', 'willing', 'to', 'go', 'for', 'aptitude', 'class'],
#  ['wont', 'until', 'trying', 'sort', 'house', 'out', 'is', 'that', 'ok'],
#  ['ar',
#   'lor',
#   'he',
#   'wan',
#   'go',
#   'horse',
#   'racing',
#   'today',
#   'mah',
#   'so',
#   'eat',
#   'earlier',
#   'lor',
#   'ate',
#   'chicken',
#   'rice'],
#  ['aha', 'awesome', 'omw', 'back', 'now', 'then'],
#  ['up', 'thk', 'so', 'until', 'shop', 'close', 'lor'],
#  ['hat', 'is', 'your', 'account', 'number'],
#  ['send', 'wrongly', 'lar'],
#  ['ey',
#   'no',
#   'ad',
#   'crap',
#   'nite',
#   'wa',
#   'borin',
#   'without',
#   'ya',
#   'boggy',
#   'with',
#   'me',
#   'boring',
#   'biatch',
#   'thanx',
#   'but',
#   'wait',
#   'til',
#   'nxt',
#   'time',
#   'il',
#   'ave',
#   'ya'],
#  ['shall', 'talk', 'to', 'him'],
#  ['ont',
#   'hesitate',
#   'you',
#   'know',
#   'this',
#   'is',
#   'the',
#   'second',
#   'time',
#   'she',
#   'ha',
#   'had',
#   'weakness',
#   'like',
#   'that',
#   'so',
#   'keep',
#   'notebook',
#   'of',
#   'what',
#   'she',
#   'eat',
#   'and',
#   'did',
#   'the',
#   'day',
#   'before',
#   'or',
#   'if',
#   'anything',
#   'changed',
#   'the',
#   'day',
#   'before',
#   'so',
#   'that',
#   'we',
#   'can',
#   'be',
#   'sure',
#   'it',
#   'nothing'],
#  ['ey', 'you', 'can', 'pay', 'with', 'salary', 'de', 'only', 'lt', 'gt'],
#  ['nother', 'month', 'need', 'chocolate', 'weed', 'and', 'alcohol'],
#  ['he',
#   'started',
#   'searching',
#   'he',
#   'will',
#   'get',
#   'job',
#   'in',
#   'few',
#   'days',
#   'he',
#   'have',
#   'great',
#   'potential',
#   'and',
#   'talent'],
#  ['eckon',
#   'need',
#   'to',
#   'be',
#   'in',
#   'town',
#   'by',
#   'eightish',
#   'to',
#   'walk',
#   'from',
#   'carpark'],
#  ['ongrats',
#   'mobile',
#   'videophones',
#   'yours',
#   'call',
#   'now',
#   'videochat',
#   'wid',
#   'your',
#   'mates',
#   'play',
#   'java',
#   'games',
#   'dload',
#   'polyph',
#   'music',
#   'noline',
#   'rentl'],
#  ['ook',
#   'at',
#   'the',
#   'fuckin',
#   'time',
#   'what',
#   'the',
#   'fuck',
#   'you',
#   'think',
#   'is',
#   'up'],
#  ['guess', 'what', 'just', 'dropped'],
#  ['arlos', 'say', 'he', 'll', 'be', 'at', 'mu', 'in', 'lt', 'gt', 'minute'],
#  ['in', 'office', 'now', 'will', 'call', 'you', 'lt', 'gt', 'min'],
#  ['eeee',
#   'miss',
#   'you',
#   'already',
#   'you',
#   'know',
#   'your',
#   'all',
#   'can',
#   'think',
#   'about',
#   'fuck',
#   'can',
#   'wait',
#   'till',
#   'next',
#   'year',
#   'when',
#   'we',
#   'will',
#   'be',
#   'together',
#   'loving',
#   'kiss'],
#  ['un',
#   'ah',
#   'the',
#   'ubi',
#   'one',
#   'say',
#   'if',
#   'wan',
#   'call',
#   'by',
#   'tomorrow',
#   'call',
#   'look',
#   'for',
#   'irene',
#   'ere',
#   'only',
#   'got',
#   'bus',
#   'ubi',
#   'cres',
#   'ubi',
#   'tech',
#   'park',
#   'ph',
#   'for',
#   'st',
#   'wkg',
#   'days',
#   'èn'],
#  ['gh',
#   'gotta',
#   'drive',
#   'back',
#   'to',
#   'sd',
#   'from',
#   'la',
#   'my',
#   'butt',
#   'is',
#   'sore'],
#  ['th', 'of', 'july'],
#  ['im',
#   'having',
#   'the',
#   'most',
#   'relaxing',
#   'time',
#   'ever',
#   'we',
#   'have',
#   'to',
#   'get',
#   'up',
#   'at',
#   'am',
#   'every',
#   'day',
#   'wa',
#   'the',
#   'party',
#   'good',
#   'the',
#   'other',
#   'night',
#   'get',
#   'home',
#   'tomorrow',
#   'at',
#   'ish'],
#  ['to',
#   'wan',
#   'come',
#   'then',
#   'come',
#   'lor',
#   'but',
#   'din',
#   'any',
#   'stripe',
#   'skirt'],
#  ['he',
#   'xmas',
#   'story',
#   'is',
#   'peace',
#   'the',
#   'xmas',
#   'msg',
#   'is',
#   'love',
#   'the',
#   'xmas',
#   'miracle',
#   'is',
#   'jesus',
#   'hav',
#   'blessed',
#   'month',
#   'ahead',
#   'amp',
#   'wish',
#   'merry',
#   'xmas'],
#  ['can', 'don', 'have', 'her', 'number'],
#  ['hange', 'again', 'it', 'one', 'next', 'to', 'escalator'],
#  ['etunde',
#   'in',
#   'class',
#   'can',
#   'you',
#   'not',
#   'run',
#   'water',
#   'on',
#   'it',
#   'to',
#   'make',
#   'it',
#   'ok',
#   'pls',
#   'now'],
#  ['ot',
#   'lot',
#   'ha',
#   'happened',
#   'here',
#   'feel',
#   'very',
#   'quiet',
#   'beth',
#   'is',
#   'at',
#   'her',
#   'aunt',
#   'and',
#   'charlie',
#   'is',
#   'working',
#   'lots',
#   'just',
#   'me',
#   'and',
#   'helen',
#   'in',
#   'at',
#   'the',
#   'mo',
#   'how',
#   'have',
#   'you',
#   'been'],
#  ['hen',
#   'wait',
#   'me',
#   'at',
#   'bus',
#   'stop',
#   'aft',
#   'ur',
#   'lect',
#   'lar',
#   'if',
#   'dun',
#   'then',
#   'go',
#   'get',
#   'my',
#   'car',
#   'then',
#   'come',
#   'back',
#   'pick'],
#  ...]

# %%
import gensim

# %%
## lets train word2ec from scratch
model = gensim.models.Word2Vec(words)

# %%
model.wv.index_to_key
# Out:
# ['to',
#  'you',
#  'the',
#  'and',
#  'in',
#  'it',
#  'is',
#  'me',
#  'my',
#  'for',
#  'your',
#  'of',
#  'call',
#  'have',
#  'on',
#  'that',
#  'now',
#  'are',
#  'or',
#  'can',
#  'but',
#  'at',
#  'not',
#  'so',
#  'get',
#  'be',
#  'ur',
#  'with',
#  'will',
#  'we',
#  'do',
#  'if',
#  'up',
#  'just',
#  'gt',
#  'lt',
#  'this',
#  'go',
#  'll',
#  'all',
#  'from',
#  'when',
#  'out',
#  'day',
#  'know',
#  'no',
#  'he',
#  'free',
#  'how',
#  'like',
#  'time',
#  'come',
#  'got',
#  'am',
#  'wa',
#  'what',
#  'there',
#  'then',
#  'only',
#  'love',
#  'text',
#  'want',
#  'good',
#  'send',
#  'need',
#  'one',
#  'txt',
#  'by',
#  'going',
#  'our',
#  'home',
#  'about',
#  'stop',
#  'an',
#  'lor',
#  'today',
#  'here',
#  'see',
#  'ok',
#  're',
#  'mobile',
#  'don',
#  'take',
#  'back',
#  'da',
#  'she',
#  'still',
#  'reply',
#  'think',
#  'phone',
#  'ou',
#  'week',
#  'later',
#  'her',
#  'any',
#  'been',
#  'new',
#  'tell',
#  'dont',
#  'co',
#  'ha',
#  'some',
#  'make',
#  'they',
#  'msg',
#  'who',
#  'hat',
#  'much',
#  'claim',
#  'say',
#  'night',
#  'him',
#  'please',
#  'pls',
#  'did',
#  'more',
#  'number',
#  'too',
#  'give',
#  'work',
#  'message',
#  'thing',
#  'min',
#  'hope',
#  'way',
#  'www',
#  've',
#  'orry',
#  'where',
#  'happy',
#  'had',
#  'ey',
#  'won',
#  'prize',
#  'great',
#  'right',
#  'should',
#  'tomorrow',
#  'said',
#  'his',
#  'friend',
#  'already',
#  'ow',
#  'ask',
#  'amp',
#  'cash',
#  'after',
#  'let',
#  'dear',
#  'wat',
#  'doing',
#  'find',
#  'tone',
#  'them',
#  'meet',
#  'very',
#  'well',
#  'really',
#  'life',
#  'morning',
#  'miss',
#  'win',
#  'uk',
#  'care',
#  'com',
#  'last',
#  'im',
#  'service',
#  'nokia',
#  'would',
#  'feel',
#  'every',
#  'contact',
#  'year',
#  'why',
#  'over',
#  'keep',
#  'something',
#  'babe',
#  'pick',
#  'sent',
#  'again',
#  'anything',
#  'before',
#  'box',
#  'cant',
#  'buy',
#  'place',
#  'sure',
#  'sorry',
#  'first',
#  'help',
#  'next',
#  'off',
#  'also',
#  'end',
#  'tonight',
#  'around',
#  'wait',
#  'wish',
#  'even',
#  'soon',
#  'sleep',
#  'gud',
#  'chat',
#  'went',
#  'show',
#  'late',
#  'could',
#  'were',
#  'per',
#  'guy',
#  'money',
#  'which',
#  'always',
#  'gonna',
#  'many',
#  'nice',
#  'down',
#  'name',
#  'someone',
#  'ell',
#  'nd',
#  'wan',
#  'hen',
#  'other',
#  'lot',
#  'pm',
#  'leave',
#  'told',
#  'special',
#  'rgent',
#  'customer',
#  'word',
#  'dun',
#  'st',
#  'person',
#  'ot',
#  'ill',
#  'coming',
#  'people',
#  'eah',
#  'ol',
#  'th',
#  'yet',
#  'guaranteed',
#  'waiting',
#  'girl',
#  'try',
#  'ppm',
#  'best',
#  'done',
#  'getting',
#  'use',
#  'may',
#  'thk',
#  'fine',
#  'heart',
#  'start',
#  'minute',
#  'ood',
#  'holiday',
#  'thanks',
#  'hour',
#  'line',
#  'offer',
#  'thought',
#  'class',
#  'didn',
#  'bit',
#  'live',
#  'lunch',
#  'stuff',
#  'month',
#  'few',
#  'mean',
#  'job',
#  'man',
#  'ust',
#  'yes',
#  'cost',
#  'ear',
#  'smile',
#  'same',
#  'being',
#  'car',
#  'id',
#  'ah',
#  'god',
#  'draw',
#  'trying',
#  'finish',
#  'talk',
#  'problem',
#  'ready',
#  'dat',
#  'account',
#  'hank',
#  'pobox',
#  'rate',
#  'mind',
#  'having',
#  'better',
#  'hi',
#  'meeting',
#  'chance',
#  'plan',
#  'ya',
#  'wk',
#  'real',
#  'never',
#  'half',
#  'weekend',
#  'world',
#  'oh',
#  'than',
#  'because',
#  'house',
#  'bt',
#  'ight',
#  'long',
#  'room',
#  'ree',
#  'luv',
#  'po',
#  'awarded',
#  'play',
#  'latest',
#  'receive',
#  'lar',
#  'liao',
#  'enjoy',
#  'ever',
#  'into',
#  'yeah',
#  'aha',
#  'birthday',
#  'another',
#  'sweet',
#  'dinner',
#  'eat',
#  'xxx',
#  'shit',
#  'cs',
#  'video',
#  'voucher',
#  'big',
#  'wanna',
#  'pic',
#  'thats',
#  'might',
#  'landline',
#  'ave',
#  'check',
#  'ello',
#  'look',
#  'wont',
#  'watch',
#  'called',
#  'boy',
#  'tv',
#  'guess',
#  'bed',
#  'pa',
#  'hear',
#  'till',
#  'camera',
#  'kiss',
#  'bad',
#  'quite',
#  'baby',
#  'age',
#  'part',
#  'bus',
#  'pay',
#  'speak',
#  'fun',
#  'early',
#  'apply',
#  'office',
#  'sat',
#  'orange',
#  'two',
#  'made',
#  'reach',
#  'between',
#  'left',
#  'code',
#  'hey',
#  'princess',
#  'den',
#  'put',
#  'didnt',
#  'everything',
#  'face',
#  'nite',
#  'leh',
#  'little',
#  'award',
#  'hrs',
#  'worry',
#  'cool',
#  'once',
#  'xx',
#  'ringtone',
#  'network',
#  'town',
#  'game',
#  'shopping',
#  'evening',
#  'working',
#  'mail',
#  'forgot',
#  'looking',
#  'dis',
#  'es',
#  'remember',
#  'enough',
#  'selected',
#  'question',
#  'while',
#  'easy',
#  'gift',
#  'without',
#  'school',
#  'hurt',
#  'afternoon',
#  'run',
#  'pound',
#  'entry',
#  'dad',
#  'ope',
#  'asked',
#  'collect',
#  'hav',
#  'missing',
#  'price',
#  'nothing',
#  'movie',
#  'came',
#  'pain',
#  'maybe',
#  'most',
#  'wanted',
#  'valid',
#  'though',
#  'collection',
#  'fuck',
#  'wife',
#  'sir',
#  'true',
#  'tmr',
#  'able',
#  'jus',
#  'til',
#  'those',
#  'join',
#  'top',
#  'must',
#  'anyway',
#  'abt',
#  'mob',
#  'since',
#  'sm',
#  'wif',
#  'until',
#  'probably',
#  'plus',
#  'away',
#  'de',
#  'actually',
#  'charge',
#  'wake',
#  'decimal',
#  'stay',
#  'sexy',
#  'answer',
#  'doe',
#  'date',
#  'ad',
#  'attempt',
#  'weekly',
#  'shall',
#  'mins',
#  'music',
#  'else',
#  'lease',
#  'hair',
#  'missed',
#  'lol',
#  'watching',
#  'colour',
#  'lei',
#  'bring',
#  'online',
#  'drink',
#  'change',
#  'book',
#  'plz',
#  'ring',
#  'optout',
#  'important',
#  'oso',
#  'xmas',
#  'et',
#  'coz',
#  'food',
#  'haha',
#  'juz',
#  'making',
#  'yours',
#  'yesterday',
#  'saw',
#  'net',
#  'update',
#  'goin',
#  'family',
#  'sch',
#  'these',
#  'either',
#  'feeling',
#  'detail',
#  'club',
#  'shop',
#  'yr',
#  'player',
#  'ont',
#  'address',
#  'test',
#  'driving',
#  'yourself',
#  'delivery',
#  'tried',
#  'national',
#  'mate',
#  'together',
#  'un',
#  'bored',
#  'lose',
#  'sae',
#  'tot',
#  'head',
#  'calling',
#  'wid',
#  'thanx',
#  'walk',
#  'story',
#  'believe',
#  'order',
#  'sms',
#  'dream',
#  'haf',
#  'trip',
#  'bonus',
#  'lesson',
#  'days',
#  'brother',
#  'await',
#  'drive',
#  'both',
#  'saying',
#  'eve',
#  'poly',
#  'chikku',
#  'row',
#  'post',
#  'full',
#  'happen',
#  'noe',
#  'smoke',
#  'busy',
#  'old',
#  'smiling',
#  'haven',
#  'second',
#  'reat',
#  'ard',
#  'http',
#  'info',
#  'drop',
#  'rite',
#  'pub',
#  'simple',
#  'its',
#  'land',
#  'suite',
#  'hello',
#  'mths',
#  'wot',
#  'friendship',
#  'sound',
#  'wil',
#  'sleeping',
#  'gr',
#  'leaving',
#  'nt',
#  'close',
#  'wen',
#  'started',
#  'took',
#  'tomo',
#  'news',
#  'hl',
#  'set',
#  'anyone',
#  'email',
#  'aft',
#  'ar',
#  'ay',
#  'thinking',
#  'ut',
#  'havent',
#  'dunno',
#  'sister',
#  'card',
#  'unsubscribe',
#  'angry',
#  'break',
#  'finished',
#  'touch',
#  'si',
#  'content',
#  'everyone',
#  'taking',
#  'statement',
#  'hit',
#  'cause',
#  'forget',
#  'doesn',
#  'tho',
#  'credit',
#  'available',
#  'neva',
#  'auction',
#  'alone',
#  'loving',
#  'okay',
#  'knw',
#  'mine',
#  'opt',
#  'gd',
#  'urgent',
#  'bout',
#  'reason',
#  'friends',
#  'choose',
#  'hot',
#  'worth',
#  'bank',
#  'each',
#  'hand',
#  'type',
#  'expires',
#  'search',
#  'yo',
#  'lucky',
#  'double',
#  'mom',
#  'treat',
#  'point',
#  'sad',
#  'fast',
#  'visit',
#  'nyt',
#  'dating',
#  'mobileupd',
#  'found',
#  'far',
#  'company',
#  'gbp',
#  'tc',
#  'college',
#  'boytoy',
#  'fancy',
#  'ltd',
#  'open',
#  'ni',
#  'quiz',
#  'match',
#  'identifier',
#  'points',
#  'rivate',
#  'friday',
#  'gone',
#  'prob',
#  'ticket',
#  'song',
#  'decided',
#  'saturday',
#  'smth',
#  'wonderful',
#  'final',
#  'chennai',
#  'rd',
#  'least',
#  'whats',
#  'wonder',
#  'sun',
#  'valentine',
#  'mum',
#  'whatever',
#  'sea',
#  'pretty',
#  'fri',
#  'outside',
#  'beautiful',
#  'fucking',
#  'lands',
#  'light',
#  'read',
#  'as',
#  'hy',
#  'hold',
#  'tel',
#  'secret',
#  'exam',
#  'ome',
#  'oredi',
#  'darlin',
#  'mrng',
#  'mr',
#  'wit',
#  'frnd',
#  'mu',
#  'operator',
#  'happened',
#  'used',
#  'camcorder',
#  'thank',
#  'wasn',
#  'abe',
#  'support',
#  'party',
#  'earlier',
#  'wrong',
#  'lovely',
#  'gal',
#  'drug',
#  'snow',
#  'listen',
#  'sub',
#  'savamob',
#  'frm',
#  'cum',
#  'kind',
#  'ten',
#  'lright',
#  'sk',
#  'project',
#  'ish',
#  'fone',
#  'blue',
#  'anytime',
#  'meant',
#  'case',
#  'course',
#  'log',
#  'their',
#  'mm',
#  'frnds',
#  'ice',
#  'ac',
#  'whole',
#  'telling',
#  'calls',
#  'seeing',
#  'ho',
#  'wq',
#  'sunday',
#  'reemsg',
#  'wkly',
#  'crazy',
#  'father',
#  'gas',
#  'john',
#  'hr',
#  'enter',
#  'luck',
#  'na',
#  'gn',
#  'knew',
#  'lso',
#  'store',
#  'mayb',
#  'unno',
#  'sell',
#  'paper',
#  'area',
#  'happiness',
#  'appy',
#  'within',
#  'park',
#  'term',
#  'couple',
#  'talking',
#  'motorola',
#  'moment',
#  'currently',
#  'ago',
#  'txts',
#  'ool',
#  'dude',
#  'lost',
#  'bslvyl',
#  'unlimited',
#  'cd',
#  'fr',
#  'side',
#  'march',
#  'balance',
#  'finally',
#  'hard',
#  'us',
#  'ir',
#  'caller',
#  'uncle',
#  'winner',
#  'invited',
#  'felt',
#  'isn',
#  'hee',
#  'oday',
#  'cut',
#  'move',
#  'etc',
#  'ongrats',
#  'hungry',
#  'valued',
#  'press',
#  'parent',
#  'dreams',
#  'difficult',
#  'film',
#  'grins',
#  'surprise',
#  'information',
#  'heard',
#  'sort',
#  'understand',
#  'extra',
#  'picking',
#  'sex',
#  'gym',
#  'through',
#  'max',
#  'redeemed',
#  'ipod',
#  'doin',
#  'supposed',
#  'india',
#  'uh',
#  'rental',
#  'seen',
#  'ex',
#  'met',
#  'via',
#  'return',
#  'reading',
#  'christmas',
#  'games',
#  'ge',
#  'swing',
#  'hanx',
#  'dnt',
#  'en',
#  'ongratulations',
#  'laptop',
#  'reveal',
#  'bcoz',
#  'semester',
#  'ive',
#  'mmm',
#  'tired',
#  'direct',
#  'ant',
#  'askd',
#  'mah',
#  'computer',
#  'shower',
#  'load',
#  'download',
#  'gotta',
#  'red',
#  'almost',
#  'hospital',
#  'confirm',
#  'charged',
#  'promise',
#  'comp',
#  'la',
#  'police',
#  'hows',
#  'slowly',
#  'loved',
#  'fact',
#  'truth',
#  'photo',
#  'asap',
#  'ude',
#  'whenever',
#  'ma',
#  'xy',
#  'ts',
#  'darren',
#  'noon',
#  'train',
#  'door',
#  'clean',
#  'blood',
#  'member',
#  'monday',
#  'remove',
#  'othing',
#  'ure',
#  'welcome',
#  'rock',
#  'slow',
#  'discount',
#  'hg',
#  'weed',
#  'rest',
#  'die',
#  'kie',
#  'leaf',
#  'single',
#  'wana',
#  'own',
#  'study',
#  'bill',
#  'orchard',
#  'carlos',
#  'bath',
#  'muz',
#  'safe',
#  'wine',
#  'lovable',
#  'txting',
#  'dogging',
#  'sending',
#  'entered',
#  'things',
#  'kay',
#  'il',
#  'complimentary',
#  'rply',
#  'checking',
#  'pas',
#  'correct',
#  'messages',
#  'crave',
#  'abiola',
#  'comin',
#  'eg',
#  'link',
#  'wap',
#  'reward',
#  'std',
#  'empty',
#  'med',
#  'eye',
#  'hw',
#  'write',
#  'bb',
#  'ringtones',
#  'rs',
#  'energy',
#  'iya',
#  'cr',
#  'ntt',
#  'getzed',
#  'fantastic',
#  'gap',
#  'king',
#  'laugh',
#  'kid',
#  'eh',
#  'cheap',
#  'warm',
#  'across',
#  'hoping',
#  'less',
#  'ove',
#  'different',
#  'asking',
#  'wc',
#  'ldn',
#  'voice',
#  'woke',
#  'rakhesh',
#  'figure',
#  'small',
#  'custcare',
#  'immediately',
#  'normal',
#  'uz',
#  'tonite',
#  'usual',
#  'wesome',
#  'lover',
#  'deep',
#  ...]

# %%
model.corpus_count
# Out:
# 5572

# %%
model.wv.similar_by_word("good")
# Out:
# [('morning', 0.999282956123352),
#  ('wa', 0.9992743730545044),
#  ('here', 0.9992648363113403),
#  ('all', 0.9992387890815735),
#  ('about', 0.9992213249206543),
#  ('very', 0.9991933107376099),
#  ('amp', 0.9991873502731323),
#  ('too', 0.9991867542266846),
#  ('in', 0.999174177646637),
#  ('where', 0.9990799427032471)]
