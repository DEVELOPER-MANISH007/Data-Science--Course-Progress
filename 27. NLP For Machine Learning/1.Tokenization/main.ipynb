# %% [markdown]
# ## Tokenization Practicals

# %%
## isntall nltk library
# ! pip install nltk

# %%
import nltk

nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\DEV_MANISH\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
corpus ="""Hello Welcome, to Manish kumar Jupyter Notebook.
 Please read the entire notebook! to become expert in NLP.
 """

# %%
print(corpus)
# Out:
# Hello Welcome, to Manish kumar Jupyter Notebook.
#  Please read the entire notebook! to become expert in NLP.

# %%
## Tokenizationo
## Sentence ----> paragraphs

from  nltk.tokenize import sent_tokenize

# %%
documents = sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello Welcome, to Manish kumar Jupyter Notebook.
# Please read the entire notebook!
# to become expert in NLP.

# %%
##  Tokenization

## pragraphs --> words
## sentance---------> words

from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Manish',
#  'kumar',
#  'Jupyter',
#  'Notebook',
#  '.',
#  'Please',
#  'read',
#  'the',
#  'entire',
#  'notebook',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Manish',
#  'kumar',
#  'Jupyter',
#  'Notebook',
#  '.',
#  'Please',
#  'read',
#  'the',
#  'entire',
#  'notebook',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Manish',
#  'kumar',
#  'Jupyter',
#  'Notebook.',
#  'Please',
#  'read',
#  'the',
#  'entire',
#  'notebook',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
