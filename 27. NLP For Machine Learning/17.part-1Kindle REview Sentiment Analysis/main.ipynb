# %% [markdown]
# ## About Dataset
#
# ### Context
#
# This is a small subset of dataset of Book reviews from Amazon Kindle Store category.
#
# ### Content
#
# 5-core dataset of product reviews from Amazon Kindle Store category from **May 1996 - July 2014**.
#
# Contains a total of **982,619 entries**.
#
# Each reviewer has at least **5 reviews** and each product has at least **5 reviews** in this dataset.
#
# ### Columns
#
# - **asin** - ID of the product, like `B000FA64PK`
# - **helpful** - Helpfulness rating of the review, example: `2/3`
# - **overall** - Rating of the product
# - **reviewText** - Text of the review
# - **reviewTime** - Time of the review (raw)
# - **reviewerID** - ID of the reviewer, like `A3SPTOKDG7WBLN`
# - **reviewerName** - Name of the reviewer
# - **summary** - Summary of the review
# - **unixReviewTime** - Unix timestamp
#
# ### Acknowledgements
#
# This dataset is taken from Amazon product data by **Julian McAuley, UCSD**.
#
# ### Inspiration
#
# - Sentiment analysis on reviews
# - Understanding how people rate usefulness of a review
# - Understanding what factors influence the helpfulness of a review
# - Fake reviews / outliers
# - Best rated product IDs
# - Similarity between products based on reviews
# - Any other interesting analysis
#
# ### ```Best Practices```
#
# 1. **Preprocessing and Cleaning**
# 2. **Train-Test Split**
# 3. **Feature Extraction**
#    - BOW (Bag of Words)
#    - TF-IDF
#    - Word2Vec
# 4. **Train ML Algorithms**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
import pandas as pd

df = pd.read_csv("all_kindle_review.csv")
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0        asin  helpful  rating  \
# 0             0       11539  B0033UV8HI  [8, 10]       3
# 1             1        5957  B002HJV4DE   [1, 1]       5
# 2             2        9146  B002ZG96I4   [0, 0]       3
# 3             3        7038  B002QHWOEU   [1, 3]       3
# 4             4        1776  B001A06VJ8   [0, 1]       4
#
#                                           reviewText   reviewTime  \
# 0  Jace Rankin may be short, but he's nothing to ...   09 2, 2010
# 1  Great short read.  I didn't want to put it dow...   10 8, 2013
# 2  I'll start by saying this is the first of four...  04 11, 2014
# 3  Aggie is Angela Lansbury who carries pocketboo...   07 5, 2014
# 4  I did not expect this type of book to be in li...  12 31, 2012
#
#        reviewerID  reviewerName                   summary  unixReviewTime
# 0  A3HHXRELK8BHQG        Ridley  Entertaining But Average      1283385600
# 1  A2RGNZ0TRF578I  Holly Butler   Terrific menage scenes!      1381190400
# ...

# %%
from IPython.display import display
import pandas as pd

print('='*60)
print('📊 EXPLORATORY DATA ANALYSIS (EDA) SUMMARY')
print('='*60)

print('\n📌 Dataset Shape')
print(df.shape)

print('\n📌 First 5 Rows')
display(df.head())

print('\n📌 Last 5 Rows')
display(df.tail())

print('\n📌 Random Sample')
display(df.sample(5))

print('\n📌 Column Names')
display(pd.DataFrame(df.columns, columns=['Columns']))

print('\n📌 Data Types')
display(df.dtypes.to_frame('Data Type'))

print('\n📌 Dataset Information')
df.info()

print('\n📌 Missing Values')
display(df.isnull().sum().to_frame('Missing Values'))

print('\n📌 Duplicate Rows')
print(df.duplicated().sum())

print('\n📌 Numerical Summary')
display(df.describe().T)

print('\n📌 Categorical Summary')
display(df.describe(include='object').T)

print('\n📌 Correlation Matrix')
display(df.corr(numeric_only=True))

print('\n✅ EDA Completed Successfully!')
# Out:
# ...
# 📊 EXPLORATORY DATA ANALYSIS (EDA) SUMMARY
# ...
#
# 📌 Dataset Shape
# (12000, 11)
#
# 📌 First 5 Rows
#    Unnamed: 0.1  Unnamed: 0        asin  helpful  rating  \
# 0             0       11539  B0033UV8HI  [8, 10]       3
# 1             1        5957  B002HJV4DE   [1, 1]       5
# 2             2        9146  B002ZG96I4   [0, 0]       3
# 3             3        7038  B002QHWOEU   [1, 3]       3
# 4             4        1776  B001A06VJ8   [0, 1]       4
#
#                                           reviewText   reviewTime  \
# 0  Jace Rankin may be short, but he's nothing to ...   09 2, 2010
# 1  Great short read.  I didn't want to put it dow...   10 8, 2013
# 2  I'll start by saying this is the first of four...  04 11, 2014
# 3  Aggie is Angela Lansbury who carries pocketboo...   07 5, 2014
# 4  I did not expect this type of book to be in li...  12 31, 2012
#
#        reviewerID  reviewerName                   summary  unixReviewTime
# ...
